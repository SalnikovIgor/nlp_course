# %% [markdown]
# # Предобработка текста

# %% [markdown]
# ### Токенизация

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
data = "All work and no play makes jack a dull boy, all work and no play"
tokens = word_tokenize(data.lower())
print(tokens)
# Out:
# ['all', 'work', 'and', 'no', 'play', 'makes', 'jack', 'a', 'dull', 'boy', ',', 'all', 'work', 'and', 'no', 'play']

# %%
print(sent_tokenize("I was going home when she rung. It was a surprise."))
# Out:
# ['I was going home when she rung.', 'It was a surprise.']

# %%
# !pip install -q razdel

# %%
from razdel import tokenize, sentenize
text = 'Кружка-термос на 0.5л (50/64 см³, 516;...)'
list(tokenize(text))
# Out:
# [Substring(0, 13, 'Кружка-термос'),
#  Substring(14, 16, 'на'),
#  Substring(17, 20, '0.5'),
#  Substring(20, 21, 'л'),
#  Substring(22, 23, '('),
#  Substring(23, 28, '50/64'),
#  Substring(29, 32, 'см³'),
#  Substring(32, 33, ','),
#  Substring(34, 37, '516'),
#  Substring(37, 38, ';'),
#  Substring(38, 41, '...'),
#  Substring(41, 42, ')')]

# %% [markdown]
# #### Регулярные выражения
#
# Исчерпывающий пост https://habr.com/ru/post/349860/

# %%
import re
word = 'supercalifragilisticexpialidocious'
re.findall('[abc]|up|super', word)
# Out:
# ['super', 'c', 'a', 'a', 'c', 'a', 'c']

# %%
re.findall('\d{1,3}', 'These are some numbers: 49 and 432312')
# Out:
# ['49', '432', '312']

# %%
re.sub('[,\.?!]','','How, to? split. text!')
# Out:
# 'How to split text'

# %%
re.sub('[^A-z]',' ','I 123 can 45 play 67 football').split()
# Out:
# ['I', 'can', 'play', 'football']

# %% [markdown]
# ### Удаление неинформативных слов

# %% [markdown]
# #### N-граммы
#
# <img src="https://res.cloudinary.com/practicaldev/image/fetch/s--466CQV1q--/c_limit%2Cf_auto%2Cfl_progressive%2Cq_66%2Cw_880/https://thepracticaldev.s3.amazonaws.com/i/78nf1vryed8h1tz05fim.gif" height=400>

# %%
unigram = list(nltk.ngrams(tokens, 1))
bigram = list(nltk.ngrams(tokens, 2))
print(unigram[:5])
print(bigram[:5])
# Out:
# [('all',), ('work',), ('and',), ('no',), ('play',)]
# [('all', 'work'), ('work', 'and'), ('and', 'no'), ('no', 'play'), ('play', 'makes')]

# %%
from nltk import FreqDist
print('Популярные униграммы: ', FreqDist(unigram).most_common(5))
print('Популярные биграммы: ', FreqDist(bigram).most_common(5))
# Out:
# Популярные униграммы:  [(('all',), 2), (('work',), 2), (('and',), 2), (('no',), 2), (('play',), 2)]
# Популярные биграммы:  [(('all', 'work'), 2), (('work', 'and'), 2), (('and', 'no'), 2), (('no', 'play'), 2), (('play', 'makes'), 1)]

# %% [markdown]
# #### Стоп-слова

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopWords = set(stopwords.words('english'))
print(stopWords)
# Out:
# {'why', 'only', 'from', "should've", 'me', 'against', 'her', 'off', 'further', 'be', 'himself', 'herself', 'ourselves', 'then', "it's", 'has', 'to', "she's", 'i', 'same', "you're", "you'd", 'doesn', 'shan', 'and', 'this', 'who', 'myself', 'by', "shan't", 'weren', 'no', 'both', 'a', 'on', 'during', 'at', 'not', 'through', 'under', "didn't", 'won', 'o', 'most', 'up', 'because', 'such', 'or', 'theirs', 'my', "won't", 'that', 'again', 'when', 'll', 'being', 'mightn', 'until', 'do', 'doing', 'aren', 'with', 'mustn', 've', 'of', 'whom', 'own', 'does', 'don', "couldn't", 'shouldn', "wouldn't", 'are', 'out', "hadn't", 'if', 'over', 'wouldn', "wasn't", 'what', 'hadn', 'they', "needn't", 'have', 'all', 'hers', 'some', 'am', 'isn', "mustn't", 'any', 'wasn', 'ours', 'is', 'will', 're', 'she', 'ma', 'above', 'an', "that'll", 'once', 'down', 'nor', 't', 'there', 'while', 's', 'just', 'it', 'here', 'he', 'now', 'each', 'itself', 'into', 'them', 'about', 'its', 'was', "haven't", 'yours', 'haven', 'our', 'other', 'so', 'how', 'you', "shouldn't", "don't", 'which', 'too', 'very', 'for', 'can', 'needn', 'yourselves', 'm', 'having', 'y', 'd', "weren't", "you'll", 'more', "you've", 'had', 'ain', 'we', 'before', 'your', 'yourself', 'those', 'as', 'between', 'the', 'themselves', 'where', 'than', 'been', 'did', 'him', "hasn't", "isn't", 'hasn', 'after', 'below', 'these', "mightn't", 'but', 'were', 'few', 'his', 'in', 'should', "aren't", 'their', 'didn', 'couldn', "doesn't"}

# %%
print([word for word in tokens if word not in stopWords])
# Out:
# ['work', 'play', 'makes', 'jack', 'dull', 'boy', ',', 'work', 'play']

# %%
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %% [markdown]
# #### Стемминг vs Лемматизация
# * ‘Caring’ -> Лемматизация -> ‘Care’
# * ‘Caring’ -> Стемминг -> ‘Car’

# %% [markdown]
# ### Стемминг
# * процесс нахождения основы слова для заданного исходного слова

# %%
from nltk.stem import PorterStemmer, SnowballStemmer
words = ["game", "gaming", "gamed", "games", "compacted"]
words_ru = ['корова', 'мальчики', 'мужчины', 'столом', 'убежала']

# %%
ps = PorterStemmer()
list(map(ps.stem, words))
# Out:
# ['game', 'game', 'game', 'game', 'compact']

# %%
ss = SnowballStemmer(language='russian')
list(map(ss.stem, words_ru))
# Out:
# ['коров', 'мальчик', 'мужчин', 'стол', 'убежа']

# %% [markdown]
# ### Лематизация
# * процесс приведения словоформы к лемме — её нормальной (словарной) форме

# %%
raw = """DENNIS: Listen, strange women lying in ponds distributing swords
is no basis for a system of government.  Supreme executive power derives from
a mandate from the masses, not from some farcical aquatic ceremony."""

raw_ru = """Не существует научных доказательств в пользу эффективности НЛП, оно
признано псевдонаукой. Систематические обзоры указывают, что НЛП основано на
устаревших представлениях об устройстве мозга, несовместимо с современной
неврологией и содержит ряд фактических ошибок."""

# %%
# !pip install -q pymorphy2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 43.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done

# %%
# 1
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
pymorphy_results = list(map(lambda x: morph.parse(x), raw_ru.split(' ')))
print(' '.join([res[0].normal_form for res in pymorphy_results]))
# Out:
# не существовать научный доказательство в польза эффективность нлп, оно
# признать псевдонаукой. систематический обзор указывают, что нлп основать на
# устаревший представление о устройство мозга, несовместимый с современной
# неврология и содержать ряд фактический ошибок.

# %%
# 2
import spacy
nlp = spacy.load('en_core_web_sm')
spacy_results = nlp(raw)
print(' '.join([token.lemma_ for token in spacy_results]))
# Out:
# DENNIS : listen , strange woman lie in pond distribute sword
#  be no basis for a system of government .   Supreme executive power derive from
#  a mandate from the masse , not from some farcical aquatic ceremony .

# %% [markdown]
# [Сравнение PyMorphy2 и PyMystem3](https://habr.com/ru/post/503420/)

# %% [markdown]
# ## Часть 2

# %% [markdown]
# #### 20 newsgroups
# Датасет с 18000 новостей, сгруппированных по 20 темам.

# %%
from sklearn.datasets import fetch_20newsgroups
newsgroups_train = fetch_20newsgroups(subset='train')

# %%
newsgroups_train.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
newsgroups_train.filenames.shape
# Out:
# (11314,)

# %% [markdown]
# #### Рассмотрим подвыборку

# %%
categories = ['alt.atheism', 'talk.religion.misc',
              'comp.graphics', 'sci.space']
newsgroups_train = fetch_20newsgroups(subset='train',
                                      categories=categories)
newsgroups_train.filenames.shape
# Out:
# (2034,)

# %%
print(newsgroups_train.data[0])
# Out:
# From: rych@festival.ed.ac.uk (R Hawkes)
# Subject: 3DS: Where did all the texture rules go?
# Lines: 21
#
# Hi,
#
# I've noticed that if you only save a model (with all your mapping planes
# positioned carefully) to a .3DS file that when you reload it after restarting
# 3DS, they are given a default position and orientation.  But if you save
# to a .PRJ file their positions/orientation are preserved.  Does anyone
# know why this information is not stored in the .3DS file?  Nothing is
# explicitly said in the manual about saving texture rules in the .PRJ file.
# I'd like to be able to read the texture rule information, does anyone have
# the format for the .PRJ file?
#
# Is the .CEL file format available from somewhere?
#
# Rych
#
# ======================================================================
# Rycharde Hawkes				email: rych@festival.ed.ac.uk
# Virtual Environment Laboratory
# Dept. of Psychology			Tel  : +44 31 650 3426
# Univ. of Edinburgh			Fax  : +44 31 667 0150
# ======================================================================

# %% [markdown]
# #### TF-IDF(напоминание)

# %% [markdown]
# $n_{\mathbb{d}\mathbb{w}}$ - число вхождений слова $\mathbb{w}$ в документ $\mathbb{d}$;<br>
# $N_{\mathbb{w}}$ - число документов, содержащих $\mathbb{w}$;<br>
# $N$ - число документов; <br><br>
#
# $p(\mathbb{w}, \mathbb{d}) = N_{\mathbb{w}} / N$ - вероятность наличия слова $\mathbb{w}$ в любом документе $\mathbb{d}$
# <br>
# $P(\mathbb{w}, \mathbb{d}, n_{\mathbb{d}\mathbb{w}}) = (N_{\mathbb{w}} / N)^{n_{\mathbb{d}\mathbb{w}}}$ - вероятность встретить $n_{\mathbb{d}\mathbb{w}}$ раз слово $\mathbb{w}$ в документе $\mathbb{d}$<br><br>
#
# $-\log{P(\mathbb{w}, \mathbb{d}, n_{\mathbb{d}\mathbb{w}})} = n_{\mathbb{d}\mathbb{w}} \cdot \log{(N / N_{\mathbb{w}})} = TF(\mathbb{w}, \mathbb{d}) \cdot IDF(\mathbb{w})$<br><br>
#
# $TF(\mathbb{w}, \mathbb{d}) = n_{\mathbb{d}\mathbb{w}}$ - term frequency;<br>
# $IDF(\mathbb{w}) = \log{(N /N_{\mathbb{w}})}$ - inverted document frequency;

# %% [markdown]
# #### Давайте векторизуем эти тексты с помощью TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# #### Некоторые параметры:
# * input : string {‘filename’, ‘file’, ‘content’}
# *  lowercase : boolean, default True
# *  preprocessor : callable or None (default)
# *  tokenizer : callable or None (default)
# *  stop_words : string {‘english’}, list, or None (default)
# *  ngram_range : tuple (min_n, max_n)
# *  max_df : float in range [0.0, 1.0] or int, default=1.0
# *  min_df : float in range [0.0, 1.0] or int, default=1
# *  max_features : int or None, default=None

# %% [markdown]
# #### Перебор параметров

# %%
# lowercase
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(newsgroups_train.data)
vectors.shape
# Out:
# (2034, 34118)

# %%
newsgroups_train.data[0]
# Out:
# "From: rych@festival.ed.ac.uk (R Hawkes)\nSubject: 3DS: Where did all the texture rules go?\nLines: 21\n\nHi,\n\nI've noticed that if you only save a model (with all your mapping planes\npositioned carefully) to a .3DS file that when you reload it after restarting\n3DS, they are given a default position and orientation.  But if you save\nto a .PRJ file their positions/orientation are preserved.  Does anyone\nknow why this information is not stored in the .3DS file?  Nothing is\nexplicitly said in the manual about saving texture rules in the .PRJ file. \nI'd like to be able to read the texture rule information, does anyone have \nthe format for the .PRJ file?\n\nIs the .CEL file format available from somewhere?\n\nRych\n\n======================================================================\nRycharde Hawkes\t\t\t\temail: rych@festival.ed.ac.uk\nVirtual Environment Laboratory\nDept. of Psychology\t\t\tTel  : +44 31 650 3426\nUniv. of Edinburgh\t\t\tFax  : +44 31 667 0150\n======================================================================\n"

# %%
vectors.todense()[0]
# Out:
# matrix([[0., 0., 0., ..., 0., 0., 0.]])

# %%
vectors.todense()[0].sum()
# Out:
# 7.545406347854756

# %% [markdown]
# #### Можем посмотреть на косинусную меру между векторами

# %%
vector = vectors.todense()[0]
(vector != 0).sum()
# Out:
# 97

# %%
import numpy as np
np.mean(list(map(lambda x: (x != 0).sum(), vectors.todense())))
# Out:
# 159.0132743362832

# %%
import numpy as np
from numpy.linalg import norm

type(vectors)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
def cosine_sim(v1, v2):
    # v1, v2 (1 x dim)
    return np.array(v1 @ v2.T / norm(v1) / norm(v2))[0][0]

# %%
dense_vectors = vectors.todense()

# %%
cosine_sim(dense_vectors[0], dense_vectors[0])
# Out:
# 1.0

# %%
cosines = []
for i in range(10):
    cosines.append(cosine_sim(dense_vectors[0], dense_vectors[i]))

# %%
# [1, 3, 2, 0, 2, 0, 2, 1, 2, 1]
cosines
# Out:
# [1.0,
#  0.034457821054194794,
#  0.012382283717249743,
#  0.058604046242764996,
#  0.029944649740318678,
#  0.04333240128880121,
#  0.021697485553365644,
#  0.06356820872419104,
#  0.029975286627438466,
#  0.016624141721744572]

# %% [markdown]
# ### Embeddings

# %%
import gensim.downloader as api
embeddings_pretrained = api.load('glove-twitter-25')

# %%
# стоп-слова, preproc
from nltk.corpus import stopwords
stopWords = set(stopwords.words('english'))
nltk.download('wordnet')
wnl = nltk.WordNetLemmatizer()

def preproc_nltk(text):
    #text = re.sub(f'[{string.punctuation}]', ' ', text)
    return ' '.join([wnl.lemmatize(word) for word in word_tokenize(text.lower()) if word not in stopWords])

st = "Oh, I think I ve landed Where there are miracles at work,  For the thirst and for the hunger Come the conference of birds"
preproc_nltk(st)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 'oh , think landed miracle work , thirst hunger come conference bird'

# %%
from gensim.models import Word2Vec

proc_words = [preproc_nltk(text).split() for text in newsgroups_train.data]
embeddings_trained = Word2Vec(proc_words, # data for model to train on
                 vector_size=100,                 # embedding vector size
                 min_count=3,             # consider words that occured at least 5 times
                 window=3).wv

# %%
proc_words[:100]
# Out:
# [[':',
#   'rych',
#   '@',
#   'festival.ed.ac.uk',
#   '(',
#   'r',
#   'hawkes',
#   ')',
#   'subject',
#   ':',
#   '3d',
#   ':',
#   'texture',
#   'rule',
#   'go',
#   '?',
#   'line',
#   ':',
#   '21',
#   'hi',
#   ',',
#   "'ve",
#   'noticed',
#   'save',
#   'model',
#   '(',
#   'mapping',
#   'plane',
#   'positioned',
#   'carefully',
#   ')',
#   '.3ds',
#   'file',
#   'reload',
#   'restarting',
#   '3d',
#   ',',
#   'given',
#   'default',
#   'position',
#   'orientation',
#   '.',
#   'save',
#   '.prj',
#   'file',
#   'positions/orientation',
#   'preserved',
#   '.',
#   'anyone',
#   'know',
#   'information',
#   'stored',
#   '.3ds',
#   'file',
#   '?',
#   'nothing',
#   'explicitly',
#   'said',
#   'manual',
#   'saving',
#   'texture',
#   'rule',
#   '.prj',
#   'file',
#   '.',
#   "'d",
#   'like',
#   'able',
#   'read',
#   'texture',
#   'rule',
#   'information',
#   ',',
#   'anyone',
#   'format',
#   '.prj',
#   'file',
#   '?',
#   '.cel',
#   'file',
#   'format',
#   'available',
#   'somewhere',
#   '?',
#   'rych',
#   '======================================================================',
#   'rycharde',
#   'hawkes',
#   'email',
#   ':',
#   'rych',
#   '@',
#   'festival.ed.ac.uk',
#   'virtual',
#   'environment',
#   'laboratory',
#   'dept',
#   '.',
#   'psychology',
#   'tel',
#   ':',
#   '+44',
#   '31',
#   '650',
#   '3426',
#   'univ',
#   '.',
#   'edinburgh',
#   'fax',
#   ':',
#   '+44',
#   '31',
#   '667',
#   '0150',
#   '======================================================================'],
#  ['subject',
#   ':',
#   ':',
#   'biblical',
#   'backing',
#   'koresh',
#   "'s",
#   '3-02',
#   'tape',
#   '(',
#   'cite',
#   'enclosed',
#   ')',
#   ':',
#   'kmcvay',
#   '@',
#   'oneb.almanac.bc.ca',
#   '(',
#   'ken',
#   'mcvay',
#   ')',
#   'organization',
#   ':',
#   'old',
#   'frog',
#   "'s",
#   'almanac',
#   'line',
#   ':',
#   '20',
#   'article',
#   '<',
#   '20apr199301460499',
#   '@',
#   'utarlg.uta.edu',
#   '>',
#   'b645zaw',
#   '@',
#   'utarlg.uta.edu',
#   '(',
#   'stephen',
#   ')',
#   'writes',
#   ':',
#   '>',
#   'seems',
#   'koresh',
#   'yet',
#   'another',
#   'messenger',
#   'got',
#   'killed',
#   '>',
#   'message',
#   'carried',
#   '.',
#   '(',
#   'say',
#   'nothing',
#   'seems',
#   ',',
#   'barring',
#   'evidence',
#   'contrary',
#   ',',
#   'koresh',
#   'simply',
#   'another',
#   'deranged',
#   'fanatic',
#   'thought',
#   'neccessary',
#   'take',
#   'whole',
#   'bunch',
#   'folk',
#   ',',
#   'child',
#   ',',
#   'satisfy',
#   'delusional',
#   'mania',
#   '.',
#   'jim',
#   'jones',
#   ',',
#   'circa',
#   '1993',
#   '.',
#   '>',
#   'mean',
#   'time',
#   ',',
#   'sure',
#   'learned',
#   'lot',
#   'evil',
#   'corruption',
#   '.',
#   '>',
#   'surprised',
#   'thing',
#   'gotten',
#   'rotten',
#   '?',
#   'nope',
#   '-',
#   'fruitcake',
#   'like',
#   'koresh',
#   'demonstrating',
#   'evil',
#   'corruption',
#   'century',
#   '.',
#   '--',
#   'old',
#   'frog',
#   "'s",
#   'almanac',
#   '-',
#   'salute',
#   'old',
#   'frog',
#   'hisse',
#   "'",
#   'f',
#   ',',
#   'ryugen',
#   'fisher',
#   '(',
#   '604',
#   ')',
#   '245-3205',
#   '(',
#   'v32',
#   ')',
#   '(',
#   '604',
#   ')',
#   '245-4366',
#   '(',
#   '2400x4',
#   ')',
#   'sco',
#   'xenix',
#   '2.3.2',
#   'gt',
#   'ladysmith',
#   ',',
#   'british',
#   'columbia',
#   ',',
#   'canada',
#   '.',
#   'serving',
#   'central',
#   'vancouver',
#   'island',
#   'public',
#   'access',
#   'usenet',
#   'internet',
#   'mail',
#   '-',
#   'home',
#   'holocaust',
#   'almanac'],
#  [':',
#   'mark.perew',
#   '@',
#   'p201.f208.n103.z1.fidonet.org',
#   'subject',
#   ':',
#   ':',
#   'comet',
#   'temporary',
#   'orbit',
#   'around',
#   'jupiter',
#   '?',
#   'x-sender',
#   ':',
#   'newtout',
#   '0.08',
#   'feb',
#   '23',
#   '1993',
#   'line',
#   ':',
#   '15',
#   'message',
#   '<',
#   'apr',
#   '19',
#   '04:55',
#   '>',
#   ',',
#   'jgarland',
#   '@',
#   'kean.ucs.mun.ca',
#   'writes',
#   ':',
#   '>',
#   'article',
#   '<',
#   '1993apr19.020359.26996',
#   '@',
#   'sq.sq.com',
#   '>',
#   ',',
#   'msb',
#   '@',
#   'sq.sq.com',
#   '(',
#   'mark',
#   'brader',
#   ')',
#   '>',
#   'writes',
#   ':',
#   'mb',
#   '>',
#   'mb',
#   '>',
#   '1970',
#   'figure',
#   'seems',
#   'unlikely',
#   'actually',
#   'anything',
#   'perijove',
#   '.',
#   'jg',
#   '>',
#   'sorry',
#   ',',
#   '_perijoves_',
#   '...',
#   "'m",
#   'used',
#   'talking',
#   'language',
#   '.',
#   'could',
#   "n't",
#   'say',
#   'periapsis',
#   'apoapsis',
#   '?',
#   '--',
#   '-',
#   'msged',
#   '2.07'],
#  [':',
#   'dpw',
#   '@',
#   'sei.cmu.edu',
#   '(',
#   'david',
#   'wood',
#   ')',
#   'subject',
#   ':',
#   'request',
#   'support',
#   'organization',
#   ':',
#   'software',
#   'engineering',
#   'institute',
#   'line',
#   ':',
#   '35',
#   'request',
#   'would',
#   'like',
#   'see',
#   'charley',
#   'wingate',
#   'respond',
#   '``',
#   'charley',
#   'challenge',
#   "''",
#   '(',
#   'judging',
#   'e-mail',
#   ',',
#   'appear',
#   'quite',
#   '.',
#   ')',
#   'clear',
#   'mr.',
#   'wingate',
#   'intends',
#   'continue',
#   'post',
#   'tangential',
#   'unrelated',
#   'article',
#   'ingoring',
#   'challenge',
#   '.',
#   'last',
#   'two',
#   're-postings',
#   'challenge',
#   ',',
#   'noted',
#   'perhaps',
#   'dozen',
#   'post',
#   'mr.',
#   'wingate',
#   ',',
#   'none',
#   'answered',
#   'single',
#   'challenge',
#   '.',
#   'seems',
#   'unmistakable',
#   'mr.',
#   'wingate',
#   'hope',
#   'question',
#   'go',
#   'away',
#   ',',
#   'level',
#   'best',
#   'change',
#   'subject',
#   '.',
#   'given',
#   'seems',
#   'rather',
#   'common',
#   'net.theist',
#   'tactic',
#   ',',
#   'would',
#   'like',
#   'suggest',
#   'impress',
#   'upon',
#   'desire',
#   'answer',
#   ',',
#   'following',
#   'manner',
#   ':',
#   '1.',
#   'ignore',
#   'future',
#   'article',
#   'mr.',
#   'wingate',
#   'address',
#   'challenge',
#   ',',
#   'answer',
#   'explictly',
#   'announces',
#   'refuse',
#   '.',
#   '--',
#   '--',
#   '2.',
#   'must',
#   'respond',
#   'one',
#   'article',
#   ',',
#   'include',
#   'within',
#   'something',
#   'similar',
#   'following',
#   ':',
#   '``',
#   'please',
#   'answer',
#   'question',
#   'posed',
#   'charley',
#   'challenge',
#   '.',
#   "''",
#   'really',
#   ',',
#   "'m",
#   'looking',
#   'humiliate',
#   'anyone',
#   ',',
#   'want',
#   'honest',
#   'answer',
#   '.',
#   'would',
#   "n't",
#   'think',
#   'honesty',
#   'would',
#   'much',
#   'ask',
#   'devout',
#   'christian',
#   ',',
#   'would',
#   '?',
#   'nevermind',
#   ',',
#   'rhetorical',
#   'question',
#   '.',
#   '--',
#   'dave',
#   'wood'],
#  [':',
#   'prb',
#   '@',
#   'access.digex.com',
#   '(',
#   'pat',
#   ')',
#   'subject',
#   ':',
#   'conference',
#   'manned',
#   'lunar',
#   'exploration',
#   '.',
#   'may',
#   '7',
#   'crystal',
#   'city',
#   'organization',
#   ':',
#   'express',
#   'access',
#   'online',
#   'communication',
#   ',',
#   'greenbelt',
#   'md',
#   'usa',
#   'line',
#   ':',
#   '9',
#   'distribution',
#   ':',
#   'na',
#   'nntp-posting-host',
#   ':',
#   'access.digex.net',
#   'aw',
#   '&',
#   'st',
#   'brief',
#   'blurb',
#   'manned',
#   'lunar',
#   'exploration',
#   'confernce',
#   'may',
#   '7th',
#   'crystal',
#   'city',
#   'virginia',
#   ',',
#   'auspex',
#   'aiaa',
#   '.',
#   'anyone',
#   'know',
#   '?',
#   'much',
#   ',',
#   'attend',
#   '?',
#   '?',
#   '?',
#   '?',
#   'anyone',
#   'want',
#   'go',
#   '?',
#   'pat'],
#  [':',
#   'nanci',
#   'ann',
#   'miller',
#   '<',
#   'nm0w+',
#   '@',
#   'andrew.cmu.edu',
#   '>',
#   'subject',
#   ':',
#   ':',
#   'genocide',
#   'caused',
#   'atheism',
#   'organization',
#   ':',
#   'sponsored',
#   'account',
#   ',',
#   'school',
#   'computer',
#   'science',
#   ',',
#   'carnegie',
#   'mellon',
#   ',',
#   'pittsburgh',
#   ',',
#   'pa',
#   'line',
#   ':',
#   '27',
#   'nntp-posting-host',
#   ':',
#   'andrew.cmu.edu',
#   'in-reply-to',
#   ':',
#   '<',
#   '1993apr5.020504.19326',
#   '@',
#   'ultb.isc.rit.edu',
#   '>',
#   'snm6394',
#   '@',
#   'ultb.isc.rit.edu',
#   '(',
#   's.n',
#   '.',
#   'mozumder',
#   ')',
#   'writes',
#   ':',
#   '>',
#   'horrible',
#   'death',
#   'resulted',
#   'atheism',
#   'anything',
#   'else',
#   '.',
#   'definitely',
#   'quite',
#   'horrible',
#   'death',
#   'result',
#   'atheist',
#   'theist',
#   '.',
#   "'m",
#   'sure',
#   'bobby',
#   'list',
#   'quite',
#   'atheist',
#   'side',
#   'fails',
#   'recognize',
#   'theist',
#   'equally',
#   'proficient',
#   'genocide',
#   '.',
#   'perhaps',
#   ',',
#   'since',
#   "'m",
#   'bit',
#   'weak',
#   'history',
#   ',',
#   'somone',
#   'would',
#   'like',
#   'give',
#   'list',
#   'war',
#   'caused/led',
#   'theist',
#   '?',
#   'think',
#   '(',
#   'hitler',
#   'claimed',
#   'christian',
#   'example',
#   ')',
#   'complete',
#   'list',
#   'would',
#   'probably',
#   'effective',
#   'showing',
#   'bobby',
#   'absurd',
#   'statement',
#   '.',
#   '>',
#   'peace',
#   ',',
#   'side',
#   'note',
#   ',',
#   'notice',
#   'always',
#   'sign',
#   'post',
#   '``',
#   'peace',
#   "''",
#   '.',
#   'perhaps',
#   'take',
#   'advice',
#   'leave',
#   'atheist',
#   'peace',
#   'belief',
#   '?',
#   '>',
#   'bobby',
#   'mozumder',
#   'nanci',
#   '.........................................................................',
#   'know',
#   '(',
#   'sure',
#   ')',
#   'author',
#   'quote',
#   ',',
#   'please',
#   'send',
#   'email',
#   '(',
#   'nm0w+',
#   '@',
#   'andrew.cmu.edu',
#   ')',
#   ':',
#   'lying',
#   'deeply',
#   'ingrained',
#   'lying',
#   'others',
#   '.'],
#  [':',
#   'wales.larrison',
#   '@',
#   'ofa123.fidonet.org',
#   'subject',
#   ':',
#   ':',
#   'clementine',
#   'mission',
#   'name',
#   'x-sender',
#   ':',
#   'newtout',
#   '0.08',
#   'feb',
#   '23',
#   '1993',
#   'line',
#   ':',
#   '27',
#   'mark',
#   'prado',
#   '>',
#   'please',
#   'go',
#   'one',
#   'step',
#   ':',
#   '>',
#   'word',
#   '``',
#   'clementine',
#   "''",
#   'associated',
#   'mining',
#   '?',
#   'old',
#   'pioneer',
#   'song',
#   '1850',
#   "'s",
#   'go',
#   'follows',
#   ':',
#   '``',
#   'cavern',
#   ',',
#   'canyon',
#   ',',
#   'excavating',
#   'mine',
#   ',',
#   'dwelt',
#   'miner',
#   ',',
#   'forty-niner',
#   ',',
#   'daughter',
#   ',',
#   'clementine',
#   "''",
#   'chorus',
#   ':',
#   '``',
#   'oh',
#   'darling',
#   ',',
#   'oh',
#   'darling',
#   ',',
#   'oh',
#   'darling',
#   'clementine',
#   '.',
#   'lost',
#   'gone',
#   'forever',
#   ',',
#   'oh',
#   'darling',
#   'clementine',
#   '.',
#   "''",
#   "'ve",
#   'also',
#   'explained',
#   '(',
#   'confirmed',
#   'reliable',
#   'data',
#   'source',
#   ')',
#   'clementine',
#   'acronym',
#   '.',
#   'something',
#   'like',
#   'combined',
#   'lunar',
#   'elemental',
#   'mapper',
#   'experiment',
#   'extended',
#   'non',
#   'terrestrial',
#   'intercept',
#   'near',
#   'earth',
#   '.',
#   'personally',
#   ',',
#   'think',
#   'acronym',
#   'made',
#   'fit',
#   'name',
#   '(',
#   'really',
#   'acronym',
#   ')',
#   '.',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'wale',
#   'larrison',
#   'space',
#   'technology',
#   'investor',
#   '--',
#   '-',
#   'maximus',
#   '2.01wb'],
#  [':',
#   'mjw19',
#   '@',
#   'cl.cam.ac.uk',
#   '(',
#   'm.j.',
#   'williams',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'rumour',
#   '3do',
#   '?',
#   '?',
#   '?',
#   'keywords',
#   ':',
#   '3do',
#   'arm',
#   'qt',
#   'compact',
#   'video',
#   'reply-to',
#   ':',
#   'mjw19',
#   '@',
#   'cl.cam.ac.uk',
#   'organization',
#   ':',
#   'national',
#   'society',
#   'inversion',
#   'cuddly',
#   'tiger',
#   'line',
#   ':',
#   '32',
#   'nntp-posting-host',
#   ':',
#   'earith.cl.cam.ac.uk',
#   'article',
#   '<',
#   '2bd07605.18974',
#   '@',
#   'news.service.uci.edu',
#   '>',
#   'rbarris',
#   '@',
#   'orion.oac.uci.edu',
#   '(',
#   'robert',
#   'c.',
#   'barris',
#   ')',
#   'writes',
#   ':',
#   '>',
#   '>',
#   'got',
#   'see',
#   'unit',
#   'displaying',
#   'full-screen',
#   'movie',
#   'using',
#   'compactvideo',
#   'codec',
#   '>',
#   '(',
#   'nice',
#   ',',
#   'little',
#   'blockiness',
#   'showing',
#   'clip',
#   'jaw',
#   'backdraft',
#   ')',
#   '>',
#   '...',
#   'high',
#   'frame',
#   'rate',
#   'boot',
#   '(',
#   'like',
#   '30fps',
#   ')',
#   '.',
#   'acorn',
#   'replay',
#   'running',
#   '25mhz',
#   'arm',
#   '3',
#   'processor',
#   '(',
#   'arm',
#   '3',
#   '20',
#   '%',
#   'slower',
#   'arm',
#   '6',
#   ')',
#   'software',
#   '(',
#   'standard',
#   'cd-rom',
#   ')',
#   '.',
#   '16',
#   'bit',
#   'colour',
#   'resolution',
#   '(',
#   'computer',
#   '8',
#   'bit',
#   'colour',
#   'support',
#   ',',
#   'real-time',
#   'dithering',
#   '...',
#   ')',
#   '.',
#   '3d0/o',
#   'supposed',
#   'couple',
#   'dsps',
#   '-',
#   'arm',
#   'used',
#   'housekeeping',
#   '.',
#   '>',
#   "'m",
#   'sure',
#   'centris/20mhz',
#   '040',
#   'stack',
#   '25',
#   'mhz',
#   'arm',
#   '>',
#   '3do',
#   'box',
#   '.',
#   'obviously',
#   'arm',
#   'faster',
#   ',',
#   'much',
#   '?',
#   '25mhz',
#   'arm',
#   '6xx',
#   'clock',
#   'around',
#   '20',
#   'arm',
#   'mips',
#   ',',
#   'say',
#   '18',
#   'flat',
#   '.',
#   'depends',
#   'really',
#   'surrounding',
#   'system',
#   'whether',
#   'talking',
#   'arm6x',
#   'arm6xx',
#   '(',
#   'latter',
#   'cache',
#   ',',
#   'essential',
#   'run',
#   'kind',
#   'speed',
#   'slower',
#   'memory',
#   ')',
#   '.',
#   "'ll",
#   'stop',
#   'saying',
#   'thing',
#   "'cos",
#   "'ll",
#   'hopefully',
#   'working',
#   'arm',
#   'graduation',
#   '...',
#   'mike',
#   'p',
#   "n't",
#   'pay',
#   'heed',
#   'rep',
#   'philip',
#   'say',
#   ';',
#   '3d0/o',
#   "n't",
#   'beat',
#   'pant',
#   '3di',
#   "'ll",
#   'eat',
#   'postscript',
#   '.',
#   '--',
#   '____________________________________________________________________________',
#   '\\',
#   '/',
#   '/',
#   'michael',
#   'williams',
#   'part',
#   'ii',
#   'computer',
#   'science',
#   'tripos',
#   '|\\/|\\/\\',
#   'mjw19',
#   '@',
#   'phx.cam.ac.uk',
#   'university',
#   'cambridge',
#   '|',
#   '|',
#   '(',
#   '__',
#   ')',
#   'cymdeithas',
#   'genedlaethol',
#   'traddodiad',
#   'troi',
#   'teigrod',
#   'mwythus',
#   'ben',
#   'waered'],
#  [':',
#   'henry',
#   '@',
#   'zoo.toronto.edu',
#   '(',
#   'henry',
#   'spencer',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'japanese',
#   'moon',
#   'landing',
#   '?',
#   'organization',
#   ':',
#   'u',
#   'toronto',
#   'zoology',
#   'line',
#   ':',
#   '14',
#   'article',
#   '<',
#   'c5kys1.c6r',
#   '@',
#   'panix.com',
#   '>',
#   'dannyb',
#   '@',
#   'panix.com',
#   '(',
#   'daniel',
#   'burstein',
#   ')',
#   'writes',
#   ':',
#   '>',
#   'short',
#   'story',
#   'newspaper',
#   'day',
#   'ago',
#   'made',
#   'sort',
#   'mention',
#   '>',
#   'japanese',
#   ',',
#   'using',
#   'sounded',
#   'like',
#   'gravity',
#   'assist',
#   ',',
#   '>',
#   'managed',
#   'crash',
#   '(',
#   'crash-land',
#   ')',
#   'package',
#   'moon',
#   '.',
#   'hiten',
#   'engineering-test',
#   'mission',
#   'spent',
#   'highly',
#   'eccentric',
#   'earth',
#   'orbit',
#   'lunar',
#   'flybys',
#   ',',
#   'inserted',
#   'lunar',
#   'orbit',
#   'using',
#   'tricky',
#   'gravity-assist-like',
#   'maneuvering',
#   '.',
#   'meant',
#   'would',
#   'crash',
#   'moon',
#   'eventually',
#   ',',
#   'since',
#   'thing',
#   'stable',
#   'lunar',
#   'orbit',
#   '(',
#   'far',
#   'anyone',
#   'know',
#   ')',
#   ',',
#   'believe',
#   'recall',
#   'hearing',
#   'recently',
#   'happen',
#   '.',
#   '--',
#   'work',
#   'one',
#   'man',
#   "'s",
#   'work',
#   '.',
#   '|',
#   'henry',
#   'spencer',
#   '@',
#   'u',
#   'toronto',
#   'zoology',
#   '-',
#   'kipling',
#   '|',
#   'henry',
#   '@',
#   'zoo.toronto.edu',
#   'utzoo',
#   '!',
#   'henry'],
#  [':',
#   'hendrix',
#   '@',
#   'oasys.dt.navy.mil',
#   '(',
#   'dane',
#   'hendrix',
#   ')',
#   'subject',
#   ':',
#   'processing',
#   'stereo',
#   'image',
#   'reply-to',
#   ':',
#   'hendrix',
#   '@',
#   'oasys.dt.navy.mil',
#   '(',
#   'dane',
#   'hendrix',
#   ')',
#   'organization',
#   ':',
#   'code',
#   '1542',
#   ',',
#   'dtmb',
#   ',',
#   'bethesda',
#   ',',
#   'md',
#   'line',
#   ':',
#   '16',
#   "'m",
#   'interested',
#   'find',
#   'involved',
#   'processing',
#   'pair',
#   'stereo',
#   'photograph',
#   '.',
#   'black-and-white',
#   'photo',
#   'would',
#   'like',
#   'obtain',
#   'surface',
#   'contour',
#   '.',
#   "'d",
#   'prefer',
#   'processing',
#   'sgi',
#   ',',
#   'would',
#   'interested',
#   'hearing',
#   'software/hardware',
#   'used',
#   'type',
#   'image',
#   'processing',
#   '.',
#   'please',
#   'email',
#   'and/or',
#   'post',
#   'comp.sys.sgi.graphics',
#   'response',
#   '.',
#   'thanks',
#   ',',
#   'dane',
#   'hendrix',
#   '|',
#   'email',
#   ':',
#   'dane',
#   '@',
#   'wizard.dt.navy.mil',
#   'dtmb',
#   '(',
#   'a.k.a',
#   '.',
#   'headquarters',
#   ',',
#   'carderock',
#   'div.',
#   ',',
#   '|',
#   'hendrix',
#   '@',
#   'oasys.dt.navy.mil',
#   'naval',
#   'surface',
#   'warfare',
#   'center',
#   ')',
#   '|',
#   'hendrix',
#   '@',
#   'nas.nasa.gov',
#   'code',
#   '1542',
#   ',',
#   'bethesda',
#   ',',
#   'md',
#   '20084-5000',
#   '|',
#   'phone',
#   ':',
#   '(',
#   '301',
#   ')',
#   '227-1340'],
#  [':',
#   'prb',
#   '@',
#   'access.digex.com',
#   '(',
#   'pat',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'comet',
#   'temporary',
#   'orbit',
#   'around',
#   'jupiter',
#   '?',
#   'organization',
#   ':',
#   'express',
#   'access',
#   'online',
#   'communication',
#   'usa',
#   'line',
#   ':',
#   '23',
#   'distribution',
#   ':',
#   'world',
#   'nntp-posting-host',
#   ':',
#   'access.digex.net',
#   'article',
#   '<',
#   '6apr199314571378',
#   '@',
#   'kelvin.jpl.nasa.gov',
#   '>',
#   'baalke',
#   '@',
#   'kelvin.jpl.nasa.gov',
#   '(',
#   'ron',
#   'baalke',
#   ')',
#   'writes',
#   ':',
#   '|comet',
#   'gehrels',
#   '3',
#   ',',
#   'discovered',
#   '1977',
#   ',',
#   'determined',
#   '|been',
#   'temporary',
#   'jovian',
#   'orbit',
#   '1970',
#   '1973.',
#   'comet',
#   'shoemaker-levy',
#   '1993e',
#   '|may',
#   'remain',
#   'orbit',
#   'around',
#   'jupiter',
#   'long',
#   'enough',
#   'allow',
#   'galileo',
#   '|make',
#   'closeup',
#   'observation',
#   '.',
#   'orbital',
#   'trajectory',
#   'comet',
#   '|shoemaker-levy',
#   'still',
#   'determined',
#   '.',
#   'positional',
#   'uncertainty',
#   's-l',
#   '1993e',
#   '?',
#   'assume',
#   'know',
#   'galileo',
#   'within',
#   'meter',
#   '.',
#   'without',
#   'hga',
#   ',',
#   "n't",
#   'pretty',
#   'good',
#   'idea',
#   ',',
#   'look',
#   'imaging',
#   '?',
#   'hga',
#   'working',
#   ',',
#   'could',
#   'slew',
#   'around',
#   'near',
#   'real',
#   'time',
#   '(',
#   'le',
#   'speed',
#   'light',
#   'delay',
#   ')',
#   '.',
#   'imaging',
#   'toutatis',
#   '?',
#   '?',
#   '?',
#   '?',
#   "n't",
#   'someone',
#   'get',
#   'lucky',
#   'guess',
#   'find',
#   'first',
#   'image',
#   '?',
#   'also',
#   ',',
#   'imagine',
#   's-l',
#   '1993e',
#   'mostly',
#   'visual',
#   'image',
#   '.',
#   'affect',
#   'imaging',
#   'mission',
#   '.',
#   'lga',
#   ',',
#   'real',
#   'tight',
#   'allocation',
#   'bandwidth',
#   '.',
#   'may',
#   'premature',
#   'hope',
#   'answer',
#   ',',
#   'thought',
#   "'d",
#   'throw',
#   'floor',
#   '.',
#   'pat'],
#  [':',
#   'zemcik',
#   '@',
#   'l',
#   '(',
#   'pavel',
#   'zemcik',
#   ')',
#   'subject',
#   ':',
#   'tseng',
#   'et4000',
#   'pixel',
#   'clock',
#   'organization',
#   ':',
#   'technical',
#   'university',
#   'brno',
#   ',',
#   'czech',
#   'republic',
#   'keywords',
#   ':',
#   'et4000',
#   'svga',
#   'pixel',
#   'clock',
#   'summary',
#   ':',
#   'anybody',
#   'know',
#   'set',
#   'et4000',
#   'svga',
#   'pixel',
#   'clock',
#   '?',
#   'line',
#   ':',
#   '19',
#   'would',
#   'like',
#   'program',
#   'tseng',
#   'et4000',
#   'nonstandard',
#   '1024x768',
#   'mode',
#   'switching',
#   'standard',
#   '1024x768',
#   'mode',
#   'using',
#   'bios',
#   'changing',
#   'timing',
#   'detail',
#   '(',
#   '0x3d4',
#   'register',
#   '0x00-0x1f',
#   ')',
#   "n't",
#   'know',
#   'select',
#   '36',
#   'mhz',
#   'pixel',
#   'clock',
#   'need',
#   '.',
#   'bios',
#   'function',
#   'selects',
#   '40',
#   'mhz',
#   '.',
#   'anybody',
#   'know',
#   'obtain',
#   'technical',
#   'info',
#   '.',
#   'also',
#   'interested',
#   'technical',
#   'information',
#   'tseng',
#   'et4000',
#   'trident',
#   '8900',
#   '9000',
#   'chipsets',
#   '.',
#   'thanks',
#   'much',
#   'pavel',
#   'zemcik',
#   'dept',
#   '.',
#   'comp',
#   '.',
#   'sci',
#   '.',
#   '&',
#   'eng',
#   '.',
#   'technical',
#   'university',
#   'brno',
#   'bozetechova',
#   '2',
#   'cs-612',
#   '66',
#   'brno',
#   'czech',
#   'republic',
#   'e-mail',
#   ':',
#   'zemcik',
#   '@',
#   'dcse.fee.vutbr.cs'],
#  [':',
#   'ddeciacco',
#   '@',
#   'cix.compulink.co.uk',
#   '(',
#   'david',
#   'deciacco',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'another',
#   'cview',
#   'question',
#   '(',
#   'wa',
#   'reply-to',
#   ':',
#   'ddeciacco',
#   '@',
#   'cix.compulink.co.uk',
#   'line',
#   ':',
#   '5',
#   'in-reply-to',
#   ':',
#   '<',
#   '20apr199312262902',
#   '@',
#   'rigel.tamu.edu',
#   '>',
#   'lmp8913',
#   '@',
#   'rigel.tamu.edu',
#   '(',
#   'preston',
#   ',',
#   'lisa',
#   ')',
#   'trident',
#   'card',
#   'fullview',
#   'work',
#   'real',
#   'gif',
#   'jpg',
#   'try',
#   '#',
#   'dave'],
#  [':',
#   'pgf',
#   '@',
#   'srl03.cacs.usl.edu',
#   '(',
#   'phil',
#   'g.',
#   'fraering',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'comet',
#   'temporary',
#   'orbit',
#   'around',
#   'jupiter',
#   '?',
#   'article-i.d',
#   '.',
#   ':',
#   'srl03.pgf.734063192',
#   'organization',
#   ':',
#   'univ',
#   '.',
#   'southwestern',
#   'louisiana',
#   'line',
#   ':',
#   '22',
#   'shag',
#   '@',
#   'aero.org',
#   '(',
#   'rob',
#   'unverzagt',
#   ')',
#   'writes',
#   ':',
#   '>',
#   'article',
#   '<',
#   '5apr199318045045',
#   '@',
#   'kelvin.jpl.nasa.gov',
#   '>',
#   'baalke',
#   '@',
#   'kelvin.jpl.nasa.gov',
#   '(',
#   'ron',
#   'baalke',
#   ')',
#   'writes',
#   ':',
#   '>',
#   '>',
#   'according',
#   'iau',
#   'circular',
#   '#',
#   '5744',
#   ',',
#   'comet',
#   'shoemaker-levy',
#   '1993e',
#   ',',
#   'may',
#   '>',
#   '>',
#   'temporarily',
#   'orbit',
#   'around',
#   'jupiter',
#   '.',
#   'comet',
#   'apparently',
#   'made',
#   '>',
#   '>',
#   'close',
#   'flyby',
#   'jupiter',
#   'sometime',
#   '1992',
#   'resulting',
#   'breakup',
#   '>',
#   '>',
#   'comet',
#   '.',
#   'attempt',
#   'determine',
#   'comet',
#   "'s",
#   'orbit',
#   'complicated',
#   '>',
#   '>',
#   'near',
#   'impossibility',
#   'measuring',
#   'comet',
#   "'s",
#   'center',
#   'mass',
#   '.',
#   '>',
#   '>',
#   '>',
#   'missing',
#   'something',
#   '--',
#   'knowing',
#   'comet',
#   "'s",
#   'center',
#   '>',
#   'mass',
#   'orbit',
#   'determination',
#   '?',
#   '>',
#   'shag',
#   "'m",
#   'sure',
#   ',',
#   'almost',
#   'sound',
#   'like',
#   'ca',
#   "n't",
#   'figure',
#   '_nucleus_',
#   'within',
#   'coma',
#   '.',
#   "'re",
#   'couple',
#   'hundred',
#   'mile',
#   ',',
#   'well',
#   ',',
#   'imagine',
#   'rest',
#   '...',
#   '--',
#   'phil',
#   'fraering',
#   '|',
#   "''",
#   'seems',
#   'like',
#   'every',
#   'day',
#   'find',
#   'sort',
#   'stuff',
#   '.',
#   'pgf',
#   '@',
#   'srl02.cacs.usl.edu|like',
#   'ancient',
#   'mayan',
#   'televison',
#   '.',
#   "''",
#   'repo',
#   'man'],
#  [':',
#   'kph2q',
#   '@',
#   'onyx.cs.virginia.edu',
#   '(',
#   'kenneth',
#   'hinckley',
#   ')',
#   'subject',
#   ':',
#   'voice',
#   'input',
#   '--',
#   'vendor',
#   'information',
#   'needed',
#   'reply-to',
#   ':',
#   'kph2q',
#   '@',
#   'onyx.cs.virginia.edu',
#   '(',
#   'kenneth',
#   'hinckley',
#   ')',
#   'organization',
#   ':',
#   'university',
#   'virginia',
#   'line',
#   ':',
#   '27',
#   'hello',
#   ',',
#   'looking',
#   'add',
#   'voice',
#   'input',
#   'capability',
#   'user',
#   'interface',
#   'developing',
#   'hp730',
#   '(',
#   'unix',
#   ')',
#   'workstation',
#   '.',
#   'would',
#   'greatly',
#   'appreciate',
#   'information',
#   'anyone',
#   'would',
#   'care',
#   'offer',
#   'voice',
#   'input',
#   'system',
#   'easily',
#   'accessible',
#   'unix',
#   'environment',
#   '.',
#   'name',
#   'adresses',
#   'applicable',
#   'vendor',
#   ',',
#   'well',
#   'experience',
#   'specific',
#   'system',
#   ',',
#   'would',
#   'helpful',
#   '.',
#   'please',
#   'respond',
#   'via',
#   'email',
#   ';',
#   'post',
#   'summary',
#   'sufficient',
#   'interest',
#   '.',
#   'thanks',
#   ',',
#   'ken',
#   'p.s',
#   '.',
#   'found',
#   'several',
#   'impressive',
#   'system',
#   'ibm',
#   'pc',
#   "'s",
#   ',',
#   'would',
#   'like',
#   'avoid',
#   'hassle',
#   'purchasing',
#   'maintaining',
#   'separate',
#   'pc',
#   'possible',
#   '.',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '-',
#   'ken',
#   'hinckley',
#   '(',
#   'kph2q',
#   '@',
#   'virginia.edu',
#   ')',
#   'university',
#   'virginia',
#   'neurosurgical',
#   'visualization',
#   'laboratory',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '-'],
#  [':',
#   'pyron',
#   '@',
#   'skndiv.dseg.ti.com',
#   '(',
#   'dillon',
#   'pyron',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'wrench',
#   'work',
#   '?',
#   'line',
#   ':',
#   '31',
#   'nntp-posting-host',
#   ':',
#   'skndiv.dseg.ti.com',
#   'reply-to',
#   ':',
#   'pyron',
#   '@',
#   'skndiv.dseg.ti.com',
#   'organization',
#   ':',
#   'ti/dseg',
#   'vax',
#   'support',
#   'article',
#   '<',
#   '25228',
#   '@',
#   'ksr.com',
#   '>',
#   ',',
#   'jfw',
#   '@',
#   'ksr.com',
#   '(',
#   'john',
#   'f.',
#   'wood',
#   ')',
#   'writes',
#   ':',
#   '>',
#   'nanderso',
#   '@',
#   'endor.sim.es.com',
#   '(',
#   'norman',
#   'anderson',
#   ')',
#   'writes',
#   ':',
#   '>',
#   '>',
#   'jmcocker',
#   '@',
#   'eos.ncsu.edu',
#   '(',
#   'mitch',
#   ')',
#   'writes',
#   ':',
#   '>',
#   '>',
#   '>',
#   'effect',
#   'one',
#   'ssrbs',
#   'recovered',
#   '>',
#   '>',
#   '>',
#   'recent',
#   'space',
#   'shuttle',
#   'launch',
#   'found',
#   'wrench',
#   '>',
#   '>',
#   '>',
#   'sort',
#   'rattling',
#   'around',
#   'apparently',
#   'inside',
#   'case',
#   '.',
#   '>',
#   '>',
#   'heard',
#   'similar',
#   'statement',
#   'local',
#   'news',
#   '(',
#   'utah',
#   ')',
#   'tonight',
#   '.',
#   'referred',
#   '>',
#   '>',
#   'tool',
#   '``',
#   '...',
#   'plier',
#   'took',
#   'ride',
#   'space',
#   '...',
#   "''",
#   '.',
#   'also',
#   '>',
#   '>',
#   'said',
#   'thiokol',
#   '(',
#   'sp',
#   '?',
#   ')',
#   'employee',
#   'reported',
#   'missing',
#   'tool',
#   'kind',
#   '>',
#   '>',
#   'assembly',
#   'one',
#   'srb',
#   '.',
#   'test',
#   'first',
#   'reusable',
#   'tool',
#   '.',
#   '>',
#   '>',
#   'assume',
#   ',',
#   ',',
#   'someone',
#   'thiokol',
#   'put',
#   '``',
#   'manager',
#   "'s",
#   'hat',
#   "''",
#   'said',
#   '>',
#   'pissing',
#   'customer',
#   'delaying',
#   'shipment',
#   'srb',
#   'look',
#   'inside',
#   '>',
#   'bad',
#   'idea',
#   ',',
#   'regardless',
#   'tool',
#   'might',
#   'ended',
#   '.',
#   '>',
#   '>',
#   'get',
#   'feeling',
#   'thiokol',
#   '``',
#   'manager',
#   "'s",
#   'hat',
#   "''",
#   'shaped',
#   'like',
#   'cone',
#   '?',
#   'pointy',
#   'find',
#   'stick',
#   'pant',
#   'better',
#   ',',
#   'closer',
#   'brain',
#   '?',
#   '--',
#   'dillon',
#   'pyron',
#   '|',
#   'opinion',
#   'expressed',
#   'ti/dseg',
#   'lewisville',
#   'vax',
#   'support',
#   '|',
#   'sender',
#   'unless',
#   'otherwise',
#   'stated',
#   '.',
#   '(',
#   '214',
#   ')',
#   '462-3556',
#   '(',
#   "'m",
#   ')',
#   '|',
#   '(',
#   '214',
#   ')',
#   '492-4656',
#   '(',
#   "'m",
#   'home',
#   ')',
#   '|texans',
#   ':',
#   'vote',
#   'robin',
#   'hood',
#   '.',
#   'need',
#   'pyron',
#   '@',
#   'skndiv.dseg.ti.com',
#   '|solutions',
#   ',',
#   'gesture',
#   '.',
#   'padi',
#   'dm-54909',
#   '|'],
#  [':',
#   'jbrown',
#   '@',
#   'batman.bmd.trw.com',
#   'subject',
#   ':',
#   ':',
#   'death',
#   'penalty',
#   '/',
#   'gulf',
#   'war',
#   'line',
#   ':',
#   '232',
#   'article',
#   '<',
#   '930419.115707.6f2.rusnews.w165w',
#   '@',
#   'mantis.co.uk',
#   '>',
#   ',',
#   'mathew',
#   '<',
#   'mathew',
#   '@',
#   'mantis.co.uk',
#   '>',
#   'writes',
#   ':',
#   '>',
#   'jbrown',
#   '@',
#   'batman.bmd.trw.com',
#   'writes',
#   ':',
#   '>',
#   '>',
#   'article',
#   '<',
#   '930414.121019.7e4.rusnews.w165w',
#   '@',
#   'mantis.co.uk',
#   '>',
#   ',',
#   'mathew',
#   '>',
#   '>',
#   '<',
#   'mathew',
#   '@',
#   'mantis.co.uk',
#   '>',
#   'writes',
#   ':',
#   '>',
#   '>',
#   '>',
#   'yes',
#   '.',
#   'fortunately',
#   'right-thinking',
#   'folk',
#   'like',
#   'good',
#   'self',
#   'power',
#   '>',
#   '>',
#   '>',
#   'therefore',
#   'deemed',
#   'acceptable',
#   'slaughter',
#   'ten',
#   'even',
#   'hundred',
#   '>',
#   '>',
#   '>',
#   'thousand',
#   'iraqi',
#   'order',
#   'liberate',
#   'oil^h^h^hkuwait',
#   '.',
#   'war',
#   ',',
#   '>',
#   '>',
#   '>',
#   'hurrah',
#   'hurrah',
#   '!',
#   '>',
#   '>',
#   '>',
#   '>',
#   'number',
#   'civilian',
#   'iraqi',
#   'death',
#   'way',
#   'over-exaggerated',
#   '>',
#   '>',
#   'exploited',
#   'anti-war',
#   'emotionalism',
#   'liberal',
#   'news',
#   'medium',
#   '.',
#   '>',
#   '>',
#   'fact',
#   'le',
#   'iraqi',
#   'died',
#   'gulf',
#   'war',
#   'civilian',
#   '>',
#   '>',
#   'war',
#   'comparable',
#   'size',
#   'century',
#   '!',
#   '>',
#   '>',
#   'let',
#   "'s",
#   'analyze',
#   'claim',
#   'little',
#   '.',
#   '``',
#   'size',
#   "''",
#   'war',
#   'defined',
#   '?',
#   '>',
#   'number',
#   'participant',
#   '?',
#   'geographical',
#   'area',
#   '?',
#   'number',
#   'country',
#   'involved',
#   '?',
#   '>',
#   'number',
#   'casualty',
#   '?',
#   'size',
#   'army',
#   ',',
#   'duration',
#   ',',
#   'number',
#   'casualty',
#   'absolute',
#   'percentage',
#   'involved',
#   ',',
#   'geographical',
#   'area',
#   'number',
#   'country',
#   ',',
#   'measure',
#   'size',
#   '.',
#   'case',
#   "'d",
#   'say',
#   'relevant',
#   'statistic',
#   'would',
#   'number',
#   'combatant',
#   '(',
#   'total',
#   'troop',
#   ')',
#   'compared',
#   'total',
#   'casualty',
#   'among',
#   'total',
#   'civilian',
#   'population',
#   'affected',
#   'geographical',
#   'area',
#   '.',
#   '>',
#   '>',
#   '``',
#   'comparable',
#   "''",
#   'war',
#   'talking',
#   '?',
#   'vietnam',
#   'korea',
#   'might',
#   'make',
#   'good',
#   'comparison',
#   '.',
#   '>',
#   '>',
#   '``',
#   'liberal',
#   'news',
#   'medium',
#   "''",
#   'talking',
#   '?',
#   '>',
#   'western',
#   'news',
#   'general',
#   ',',
#   'particular',
#   'american',
#   '``',
#   'mass',
#   'medium',
#   "''",
#   ':',
#   'cbs',
#   ',',
#   'nbc',
#   ',',
#   'abc',
#   ',',
#   'etc',
#   '.',
#   'general',
#   'tone',
#   'news',
#   'whole',
#   'war',
#   'one',
#   '``',
#   'poor',
#   ',',
#   'poor',
#   'iraqi',
#   "''",
#   'along',
#   '``',
#   'look',
#   'precisely',
#   'cruise',
#   'missile',
#   'blew',
#   'building',
#   'bit',
#   "''",
#   '.',
#   '>',
#   '>',
#   'due',
#   'mostly',
#   '>',
#   '>',
#   'short',
#   'duration',
#   'coupled',
#   'precise',
#   'surgical',
#   'bombing',
#   'technique',
#   '>',
#   '>',
#   'technically',
#   'possible',
#   'recently',
#   '.',
#   '>',
#   '>',
#   'suspect',
#   'medical',
#   'advance',
#   'may',
#   'something',
#   '.',
#   'agree',
#   '.',
#   '>',
#   '>',
#   '>',
#   'innocent',
#   'people',
#   'died',
#   'blanket-bombing',
#   'ww2',
#   '?',
#   '>',
#   '>',
#   "n't",
#   'hear',
#   'bemoaning',
#   '!',
#   '>',
#   '>',
#   'perhaps',
#   'topic',
#   "n't",
#   'cropped',
#   '.',
#   'want',
#   'opinion',
#   ',',
#   'think',
#   '>',
#   'blanket',
#   'bombing',
#   'german',
#   'city',
#   'end',
#   'world',
#   'war',
#   'two',
#   '>',
#   'appalling',
#   'act',
#   'wholesale',
#   'slaughter',
#   'country',
#   'committed',
#   '>',
#   'century',
#   '.',
#   'bomber',
#   'harris',
#   'hero',
#   'mine',
#   '.',
#   'perhaps',
#   '.',
#   'maybe',
#   'atomic',
#   'bomb',
#   'mistake',
#   '.',
#   "'s",
#   'easy',
#   'say',
#   '``',
#   'enlightened',
#   "''",
#   'viewpoint',
#   '90',
#   "'s",
#   ',',
#   'right',
#   '?',
#   'back',
#   ',',
#   '*',
#   'all-out',
#   '*',
#   'war',
#   ',',
#   'germany',
#   'japan',
#   'squashed',
#   '.',
#   ',',
#   'million',
#   'british',
#   'already',
#   'died',
#   ',',
#   'hundred',
#   'thousand',
#   'french',
#   ',',
#   'couple',
#   'hundread',
#   'thousand',
#   'american',
#   ',',
#   'million',
#   'russian',
#   ',',
#   'mention',
#   'million',
#   'jew',
#   ',',
#   'pole',
#   ',',
#   'people',
#   'slavic',
#   'descent',
#   'german',
#   'concentration',
#   'camp',
#   '.',
#   'thing',
#   'considered',
#   ',',
#   'fire-bombings',
#   'atomic',
#   'bomb',
#   'essential',
#   '(',
#   'therefore',
#   'justified',
#   ')',
#   'bringing',
#   'war',
#   'quick',
#   'end',
#   'avoid',
#   'even',
#   'greater',
#   'allied',
#   'loss',
#   '.',
#   ',',
#   'one',
#   ',',
#   "n't",
#   'regret',
#   '.',
#   '>',
#   '>',
#   '>',
#   'war',
#   'never',
#   'exact',
#   'science',
#   ',',
#   '>',
#   '>',
#   'smart',
#   'bomb',
#   ',',
#   "'s",
#   'becoming',
#   'exact',
#   'smaller',
#   'percentage',
#   '>',
#   '>',
#   'civilian',
#   'casualty',
#   '.',
#   'sometimes',
#   'mistake',
#   'made',
#   ';',
#   'target',
#   '>',
#   '>',
#   'misidentified',
#   ';',
#   'innocent',
#   'die',
#   '.',
#   "'s",
#   'war',
#   'way',
#   'really',
#   '.',
#   '>',
#   '>',
#   'entrenched',
#   'political',
#   'ruler',
#   'operating',
#   'selfish',
#   'interest',
#   'without',
#   '>',
#   'regard',
#   'life',
#   'people',
#   ',',
#   '*',
#   '*',
#   'way',
#   'war',
#   'really',
#   '.',
#   'sure',
#   '.',
#   "'s",
#   'people',
#   'suffer',
#   '.',
#   'reason',
#   'depose',
#   '``',
#   'entrenched',
#   'political',
#   'ruler',
#   'operating',
#   'selfish',
#   'interest',
#   "''",
#   '!',
#   'mean',
#   'applies',
#   'ally',
#   'well',
#   '?',
#   '?',
#   '>',
#   '>',
#   'fuss',
#   'kuwait',
#   'east',
#   'timor',
#   ',',
#   'bosnia',
#   ',',
#   'even',
#   'tibet',
#   '?',
#   '>',
#   'iraq',
#   'bad',
#   ',',
#   'still',
#   'selling',
#   'stuff',
#   'couple',
#   'week',
#   '>',
#   'started',
#   'bombing',
#   '?',
#   'make',
#   'claim',
#   'effort',
#   'justify',
#   'misguided',
#   'foreign',
#   'policy',
#   'west',
#   'war',
#   '.',
#   'evident',
#   'west',
#   ',',
#   'especially',
#   'america',
#   ',',
#   'misjudged',
#   'hussein',
#   'drastically',
#   '.',
#   'hussein',
#   'invaded',
#   'kuwait',
#   'threatened',
#   'militarily',
#   'corner',
#   'significant',
#   'portion',
#   "world's",
#   'oil',
#   'supply',
#   ',',
#   'stopped',
#   '.',
#   'sure',
#   'war',
#   'could',
#   'prevented',
#   'judicious',
#   'concerted',
#   'effort',
#   'part',
#   'west',
#   'hussein',
#   'invaded',
#   'kuwait',
#   ',',
#   'still',
#   '*',
#   'hussein',
#   '*',
#   'responsible',
#   'decision',
#   'invade',
#   '.',
#   ',',
#   'strong',
#   'response',
#   'west',
#   'required',
#   '.',
#   '>',
#   '>',
#   '>',
#   'mathew',
#   ',',
#   'sarcasm',
#   'noted',
#   'completely',
#   'off-base',
#   '.',
#   '>',
#   '>',
#   'come',
#   'sounding',
#   'like',
#   'complete',
#   'peace-nik',
#   'idiot',
#   ',',
#   'although',
#   '>',
#   '>',
#   'feel',
#   'sure',
#   'intent',
#   '.',
#   '>',
#   '>',
#   "'s",
#   'intent',
#   '?',
#   'sound',
#   'like',
#   'loving',
#   'christian',
#   '?',
#   'well',
#   ',',
#   '>',
#   'good',
#   'job',
#   '.',
#   'well',
#   ',',
#   "'s",
#   '``',
#   'loving',
#   "''",
#   'allow',
#   'hussein',
#   'hitler',
#   'gobble',
#   'nearby',
#   'country',
#   'keep',
#   '.',
#   'allow',
#   'continue',
#   'mass',
#   'slaughter',
#   'certain',
#   'people',
#   'dominion',
#   '.',
#   ',',
#   "'d",
#   'say',
#   'yes',
#   ',',
#   'stopping',
#   'hussein',
#   '``',
#   'loving',
#   "''",
#   'thing',
#   'people',
#   'involved',
#   'set',
#   'mind',
#   'military',
#   'conquest',
#   '.',
#   '>',
#   '>',
#   '>',
#   'iraqi',
#   'war',
#   'wrong',
#   ',',
#   'eh',
#   '?',
#   "'m",
#   'sure',
#   'appeasement',
#   'would',
#   '>',
#   '>',
#   'worked',
#   'better',
#   'war',
#   ',',
#   'like',
#   'ww2',
#   ',',
#   'eh',
#   '?',
#   '>',
#   '>',
#   'even',
#   'mentioned',
#   'appeasement',
#   '?',
#   'make',
#   'think',
#   'situation',
#   '>',
#   'even',
#   'remotely',
#   'analogous',
#   'world',
#   'war',
#   'two',
#   '?',
#   'mentioned',
#   '.',
#   "n't",
#   'intervened',
#   ',',
#   'allowing',
#   'hussein',
#   'keep',
#   'kuwait',
#   ',',
#   'would',
#   'appeasement',
#   '.',
#   'precisely',
#   'lesson',
#   'world',
#   'learned',
#   'ww2',
#   'motivated',
#   'western',
#   'alliance',
#   'war',
#   '.',
#   'letting',
#   'hitler',
#   'take',
#   'austria',
#   'czechoslavkia',
#   'stop',
#   'ww2',
#   'happening',
#   ',',
#   'letting',
#   'hussein',
#   'keep',
#   'kuwait',
#   'would',
#   'stopped',
#   'eventual',
#   'gulf',
#   'war',
#   'protect',
#   'saudi',
#   'arabia',
#   '.',
#   '>',
#   '>',
#   '>',
#   'guess',
#   '>',
#   '>',
#   "n't",
#   'fought',
#   'ww2',
#   'either',
#   '--',
#   'think',
#   'innocent',
#   '>',
#   '>',
#   'german',
#   'civilian',
#   'killed',
#   'dresden',
#   'hamburg',
#   '.',
#   '>',
#   '>',
#   'yes',
#   ',',
#   '.',
#   'german',
#   'human',
#   ',',
#   'know',
#   '.',
#   '>',
#   'sure',
#   '.',
#   'truly',
#   'unfortunate',
#   'followed',
#   'hitler',
#   'grandiose',
#   'quest',
#   '``',
#   'thousand',
#   'year',
#   'reich',
#   "''",
#   '.',
#   'consequence',
#   'stemmed',
#   '.',
#   '>',
#   '>',
#   'tyrant',
#   'like',
#   'hussein',
#   '*',
#   '*',
#   'stopped',
#   '.',
#   'kind',
#   "n't",
#   'understand',
#   '>',
#   '>',
#   'diplomacy',
#   ';',
#   'understand',
#   'point',
#   'gun',
#   '.',
#   'regret',
#   '>',
#   '>',
#   'bush',
#   'wimped',
#   "n't",
#   'military',
#   'roll',
#   'baghdad',
#   ',',
#   '>',
#   '>',
#   'hussein',
#   'still',
#   'power',
#   'iraqi',
#   'people',
#   "'s",
#   'sacrifice',
#   '(',
#   '>',
#   '>',
#   'mention',
#   '357',
#   'american',
#   'died',
#   ')',
#   'naught',
#   '.',
#   '>',
#   '>',
#   'look',
#   'forward',
#   'hearing',
#   'incisive',
#   'comment',
#   'east',
#   'timor',
#   'tibet',
#   '.',
#   '>',
#   'say',
#   '?',
#   'anything',
#   'particular',
#   '?',
#   '>',
#   '>',
#   'poor',
#   ',',
#   'poor',
#   'rodney',
#   'king',
#   '!',
#   'ever',
#   'stop',
#   'think',
#   '*',
#   '*',
#   '>',
#   '>',
#   'jury',
#   'first',
#   'trial',
#   'brought',
#   'back',
#   'verdict',
#   '``',
#   'guilty',
#   "''",
#   '?',
#   '>',
#   '>',
#   'yes',
#   '.',
#   'amongst',
#   'thing',
#   'thought',
#   '``',
#   'hmm',
#   ',',
#   "'s",
#   'awful',
#   'lot',
#   'white',
#   '>',
#   'people',
#   'jury',
#   '.',
#   "''",
#   '?',
#   '*',
#   'policeman',
#   '*',
#   'trial',
#   'rodney',
#   'king',
#   '!',
#   '!',
#   'american',
#   'law',
#   'deserved',
#   'jury',
#   '*',
#   '*',
#   'peer',
#   '!',
#   'black',
#   'officer',
#   'involved',
#   ',',
#   "'m",
#   'sure',
#   'would',
#   'black',
#   'juror',
#   '.',
#   'point',
#   '(',
#   'allegedly',
#   'racial',
#   'motivation',
#   ')',
#   'really',
#   'shallow',
#   '.',
#   '>',
#   '>',
#   '>',
#   'foaming',
#   'mouth',
#   'blood',
#   '>',
#   '>',
#   'policeman',
#   'certainly',
#   'looked',
#   'video',
#   'tape',
#   '.',
#   '>',
#   '>',
#   'jury',
#   'looked',
#   '*',
#   '*',
#   'evidence',
#   ',',
#   'evidence',
#   '>',
#   '>',
#   'seen',
#   '.',
#   '>',
#   '>',
#   'see',
#   'bunch',
#   'policeman',
#   'beating',
#   'someone',
#   ...],
#  [':',
#   'dpage',
#   '@',
#   'ra.csc.ti.com',
#   '(',
#   'doug',
#   'page',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'quaint',
#   'u',
#   'archaism',
#   'nntp-posting-host',
#   ':',
#   'ra',
#   'organization',
#   ':',
#   'texas',
#   'instrument',
#   'line',
#   ':',
#   '41',
#   'article',
#   '<',
#   'c512wc.b0m.1',
#   '@',
#   'cs.cmu.edu',
#   '>',
#   ',',
#   'nickh',
#   '@',
#   'cs.cmu.edu',
#   '(',
#   'nick',
#   'haines',
#   ')',
#   'writes',
#   ':',
#   '|',
#   '>',
#   'article',
#   '<',
#   '1993apr2.170157.24251',
#   '@',
#   'ke4zv.uucp',
#   '>',
#   'gary',
#   '@',
#   'ke4zv.uucp',
#   '(',
#   'gary',
#   'coffman',
#   ')',
#   'writes',
#   ':',
#   '|',
#   '>',
#   '<',
#   'stuff',
#   'deleted',
#   '>',
#   '|',
#   '>',
#   'course',
#   'unit',
#   'force',
#   'name',
#   'weight',
#   ',',
#   '|',
#   '>',
#   'order',
#   'use',
#   'need',
#   'keep',
#   'useful',
#   'constant',
#   'like',
#   '|',
#   '>',
#   'omnipresent',
#   '32.',
#   '?',
#   '?',
#   '?',
#   '?',
#   'ft/sec^2',
#   'around',
#   '.',
#   '|',
#   '>',
#   '|',
#   '>',
#   'maybe',
#   "'d",
#   'like',
#   'go',
#   'system',
#   '_so_',
#   'natural',
#   '|',
#   '>',
#   '_so_',
#   'easy',
#   'use',
#   ',',
#   'gary',
#   '?',
#   "'re",
#   ',',
#   'figure',
#   'u',
#   '|',
#   '>',
#   'weight',
#   '17',
#   'barrel',
#   'quart',
#   'foo',
#   '(',
#   'density',
#   '17lb',
#   '2',
#   '3/4',
#   'oz',
#   'per',
#   '|',
#   '>',
#   'cubic',
#   'foot',
#   ')',
#   'moon',
#   '(',
#   'gravity',
#   '5',
#   'ft',
#   '7',
#   '3/32',
#   'in/sec^2',
#   ')',
#   '.',
#   'let',
#   "'s",
#   'face',
#   ',',
#   '|',
#   '>',
#   'even',
#   'imperial',
#   'system',
#   'us',
#   'basically',
#   'metric',
#   'way',
#   'relating',
#   '|',
#   '>',
#   'quantity',
#   '(',
#   'i.e',
#   '.',
#   'would',
#   'written',
#   '5.59',
#   'ft/sec^2',
#   ')',
#   ';',
#   '|',
#   '>',
#   'thing',
#   "'re",
#   'hanging',
#   'right',
#   'express',
#   'quantity',
#   '|',
#   '>',
#   '1731',
#   'inch',
#   ',',
#   '144.25',
#   'foot',
#   ',',
#   '48.0833',
#   'yard',
#   '2.186',
#   'chain',
#   '.',
#   '|',
#   '>',
#   'everyone',
#   'else',
#   'saying',
#   '_why_',
#   'want',
#   '?',
#   '|',
#   '>',
#   '|',
#   '>',
#   'apparent',
#   'remaining',
#   'complexity',
#   'si',
#   'system',
#   'due',
#   '|',
#   '>',
#   'multiplicity',
#   'aforesaid',
#   'prefix',
#   '.',
#   'fact',
#   "'s",
#   'going',
#   '(',
#   '|',
#   '>',
#   'fundamental',
#   'difference',
#   'si',
#   'imperial',
#   ')',
#   '|',
#   '>',
#   'exactly',
#   'one',
#   'unit',
#   'type',
#   ',',
#   'value',
#   'type',
#   '|',
#   '>',
#   'expressed',
#   'multiple',
#   'unit',
#   '.',
#   'mean',
#   'like',
#   ':',
#   'second',
#   ',',
#   'minute',
#   ',',
#   'hour',
#   ',',
#   'day',
#   ',',
#   'month',
#   ',',
#   'year',
#   '.',
#   '.',
#   '.',
#   ':',
#   '-',
#   ')',
#   'remember',
#   ',',
#   'fahrenheit',
#   'temperature',
#   'scale',
#   'also',
#   'centigrade',
#   'scale',
#   '.',
#   'revisionist',
#   'tell',
#   'history',
#   'something',
#   'like',
#   ':',
#   'coldest',
#   'point',
#   'particular',
#   'russian',
#   'winter',
#   'marked',
#   'thermometer',
#   'body',
#   'temperature',
#   'volunteer',
#   '(',
#   'turn',
#   'sick',
#   ',',
#   'ca',
#   "n't",
#   'win',
#   "'em",
#   ')',
#   '.',
#   'space',
#   'mark',
#   'thermometer',
#   'divided',
#   'hundredth',
#   '.',
#   ':',
#   '-',
#   ')',
#   'fwiw',
#   ',',
#   'doug',
#   'page',
#   '*',
#   '*',
#   '*',
#   'opinion',
#   'mine',
#   '(',
#   'maybe',
#   ')',
#   ',',
#   'necessarily',
#   'represent',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   '*',
#   'employer',
#   '(',
#   'sane',
#   'person',
#   ',',
#   'fot',
#   'matter',
#   ')',
#   '.',
#   '*',
#   '*',
#   '*'],
#  [':',
#   'henry',
#   '@',
#   'zoo.toronto.edu',
#   '(',
#   'henry',
#   'spencer',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'orion',
#   'drive',
#   'vacuum',
#   '--',
#   '?',
#   'organization',
#   ':',
#   'u',
#   'toronto',
#   'zoology',
#   'line',
#   ':',
#   '17',
#   'article',
#   '<',
#   '1quh78innf45',
#   '@',
#   'elroy.jpl.nasa.gov',
#   '>',
#   'pjs',
#   '@',
#   'euclid.jpl.nasa.gov',
#   'writes',
#   ':',
#   '>',
#   '>',
#   '>',
#   'national',
#   'air',
#   '&',
#   'space',
#   'museum',
#   'prototype',
#   'film',
#   '.',
#   '>',
#   '>',
#   '>',
#   ',',
#   'year',
#   'ago',
#   ',',
#   'prototype',
#   'display',
#   '...',
#   '>',
#   '>',
#   'great',
#   '!',
#   "'ll",
#   'visit',
#   'national',
#   'air',
#   'space',
#   'museum',
#   'end',
#   '>',
#   '>',
#   'month',
#   '...',
#   '>',
#   '>',
#   'sorry',
#   'put',
#   'damper',
#   'plan',
#   ',',
#   'three',
#   'week',
#   'ago',
#   '>',
#   "n't",
#   '.',
#   'would',
#   'known',
#   'look',
#   ',',
#   'course',
#   ',',
#   '>',
#   'combed',
#   'space',
#   'exhibit',
#   'pretty',
#   'thoroughly',
#   'something',
#   'like',
#   '>',
#   'would',
#   'caught',
#   'attention',
#   'instantly',
#   '.',
#   "n't",
#   'especially',
#   'prominent',
#   ',',
#   'recall',
#   '.',
#   'however',
#   ',',
#   'quite',
#   'possibly',
#   'longer',
#   'display',
#   ';',
#   'nasm',
#   ',',
#   'like',
#   'museum',
#   ',',
#   'much',
#   'stuff',
#   'display',
#   ',',
#   'rotate',
#   'display',
#   'occasionally',
#   '.',
#   '--',
#   'work',
#   'one',
#   'man',
#   "'s",
#   'work',
#   '.',
#   '|',
#   'henry',
#   'spencer',
#   '@',
#   'u',
#   'toronto',
#   'zoology',
#   '-',
#   'kipling',
#   '|',
#   'henry',
#   '@',
#   'zoo.toronto.edu',
#   'utzoo',
#   '!',
#   'henry'],
#  [':',
#   'edm',
#   '@',
#   'twisto.compaq.com',
#   '(',
#   'ed',
#   'mccreary',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'federal',
#   'hearing',
#   'in-reply-to',
#   ':',
#   'dmcgee',
#   '@',
#   'uluhe.soest.hawaii.edu',
#   "'s",
#   'message',
#   'fri',
#   ',',
#   '16',
#   'apr',
#   '1993',
#   '04',
#   ':',
#   '21:09',
#   'gmt',
#   'organization',
#   ':',
#   'compaq',
#   'computer',
#   'corp',
#   'distribution',
#   ':',
#   'usa',
#   'line',
#   ':',
#   '19',
#   '>',
#   '>',
#   '>',
#   '>',
#   '>',
#   'fri',
#   ',',
#   '16',
#   'apr',
#   '1993',
#   '04:21:09',
#   'gmt',
#   ',',
#   'dmcgee',
#   '@',
#   'uluhe.soest.hawaii.edu',
#   '(',
#   'mcgee',
#   ')',
#   'said',
#   ':',
#   'dm',
#   '>',
#   'fact',
#   'rumor',
#   '....',
#   '?',
#   'madalyn',
#   'murray',
#   "o'hare",
#   'atheist',
#   'eliminated',
#   'dm',
#   '>',
#   'use',
#   'bible',
#   'reading',
#   'prayer',
#   'public',
#   'school',
#   '15',
#   'year',
#   'ago',
#   'dm',
#   '>',
#   'going',
#   'appear',
#   'fcc',
#   'petition',
#   'stop',
#   'reading',
#   'dm',
#   '>',
#   'gospel',
#   'airway',
#   'america',
#   '.',
#   'also',
#   'campaigning',
#   'remove',
#   'dm',
#   '>',
#   'christmas',
#   'program',
#   ',',
#   'song',
#   ',',
#   'etc',
#   'public',
#   'school',
#   '.',
#   'true',
#   'dm',
#   '>',
#   'mail',
#   'federal',
#   'communication',
#   'commission',
#   '1919',
#   'h',
#   'street',
#   'washington',
#   'dc',
#   'dm',
#   '>',
#   '20054',
#   'expressing',
#   'opposition',
#   'request',
#   '.',
#   'reference',
#   'petition',
#   'number',
#   'dm',
#   '>',
#   '2493.',
#   'false',
#   '.',
#   'story',
#   'going',
#   'around',
#   'year',
#   '.',
#   "'s",
#   'drop',
#   'truth',
#   '.',
#   'note',
#   "n't",
#   'care',
#   "o'hare",
#   '(',
#   "o'hair",
#   '?',
#   ')',
#   ',',
#   'one',
#   'thing',
#   "'s",
#   'guilty',
#   '.',
#   '--',
#   'ed',
#   'mccreary',
#   ',',
#   '__o',
#   'edm',
#   '@',
#   'twisto.compaq.com',
#   '_-\\_',
#   '<',
#   ',',
#   "''",
#   'laughter',
#   ',',
#   'would',
#   'tao',
#   '.',
#   "''",
#   '(',
#   '*',
#   ')',
#   '/',
#   "'",
#   '(',
#   '*',
#   ')'],
#  [':',
#   'aws',
#   '@',
#   'iti.org',
#   '(',
#   'allen',
#   'w.',
#   'sherzer',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'conference',
#   'manned',
#   'lunar',
#   'exploration',
#   '.',
#   'may',
#   '7',
#   'crystal',
#   'city',
#   'organization',
#   ':',
#   'evil',
#   'genius',
#   'better',
#   'tomorrow',
#   'distribution',
#   ':',
#   'na',
#   'line',
#   ':',
#   '19',
#   'article',
#   '<',
#   'c5rhoc.fty',
#   '@',
#   'news.cso.uiuc.edu',
#   '>',
#   'jbh55289',
#   '@',
#   'uxa.cso.uiuc.edu',
#   '(',
#   'josh',
#   'hopkins',
#   ')',
#   'writes',
#   ':',
#   '>',
#   'remeber',
#   'reading',
#   'comment',
#   'general',
#   'dynamic',
#   'tied',
#   ',',
#   '>',
#   'connection',
#   'proposal',
#   'early',
#   'manned',
#   'landing',
#   '.',
#   'sorry',
#   "n't",
#   '>',
#   'rember',
#   'heard',
#   ',',
#   "'m",
#   'fairly',
#   'sure',
#   'somewhere',
#   'reputable',
#   '.',
#   '>',
#   'anyone',
#   'else',
#   'know',
#   'anything',
#   'angle',
#   '?',
#   'mean',
#   'anything',
#   'gd',
#   'approach',
#   ',',
#   'article',
#   'recent',
#   'avation',
#   'week',
#   '.',
#   "n't",
#   'remember',
#   'exact',
#   'date',
#   'recent',
#   '.',
#   'allen',
#   '--',
#   '+',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '-+',
#   '|',
#   'lady',
#   'astor',
#   ':',
#   '``',
#   'sir',
#   ',',
#   'husband',
#   'would',
#   'poison',
#   'coffee',
#   '!',
#   "''",
#   '|',
#   '|',
#   'w.',
#   'churchill',
#   ':',
#   '``',
#   'madam',
#   ',',
#   'wife',
#   ',',
#   'would',
#   'drink',
#   '.',
#   "''",
#   '|',
#   '+',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '56',
#   'day',
#   'first',
#   'flight',
#   'dcx',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '-+'],
#  [':',
#   'neideck',
#   '@',
#   'nestvx.enet.dec.com',
#   '(',
#   'burkhard',
#   'neidecker-lutz',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'rumour',
#   '3do',
#   '?',
#   '?',
#   '?',
#   'organization',
#   ':',
#   'cec',
#   'karlsruhe',
#   'line',
#   ':',
#   '17',
#   'nntp-posting-host',
#   ':',
#   'nestvx',
#   'article',
#   '<',
#   '1993apr15.164940.11632',
#   '@',
#   'mercury.unt.edu',
#   '>',
#   'sean',
#   'mcmains',
#   '<',
#   'mcmains',
#   '@',
#   'unt.edu',
#   '>',
#   'writes',
#   ':',
#   '>',
#   'wow',
#   '!',
#   '68070',
#   '!',
#   "'d",
#   'interested',
#   'get',
#   'hand',
#   'one',
#   ',',
#   '>',
#   'especially',
#   'considering',
#   'fact',
#   'motorola',
#   'yet',
#   'released',
#   '>',
#   '68060',
#   ',',
#   'supposedly',
#   'next',
#   '680x0',
#   'lineup',
#   '.',
#   '8-d',
#   '68070',
#   'variation',
#   '68010',
#   'done',
#   'year',
#   'ago',
#   'european',
#   'partner',
#   'motorola',
#   '.',
#   'integrated',
#   'i/o',
#   'controller',
#   'half',
#   'mmu',
#   ',',
#   'otherwise',
#   "'s",
#   '68010.',
#   'think',
#   '8086',
#   '80186',
#   '.',
#   'burkhard',
#   'neidecker-lutz',
#   'distributed',
#   'multimedia',
#   'group',
#   ',',
#   'cec',
#   'karlsruhe',
#   'eerp',
#   'portfolio',
#   'manager',
#   'software',
#   'motion',
#   'picture',
#   '&',
#   'berkom',
#   'ii',
#   'project',
#   'multimedia',
#   'base',
#   'technology',
#   'digital',
#   'equipment',
#   'corporation',
#   'neidecker',
#   '@',
#   'nestvx.enet.dec.com'],
#  [':',
#   'jmeritt',
#   '@',
#   'mental.mitre.org',
#   'subject',
#   ':',
#   'god',
#   "'s",
#   'promise',
#   'peace',
#   'organization',
#   ':',
#   'utexas',
#   'mail-to-news',
#   'gateway',
#   'line',
#   ':',
#   '6',
#   'nntp-posting-host',
#   ':',
#   'cs.utexas.edu',
#   'psa',
#   '145:9',
#   'lord',
#   'good',
#   ':',
#   'tender',
#   'mercy',
#   'work',
#   '.',
#   'jer',
#   '13:14',
#   'dash',
#   'one',
#   'another',
#   ',',
#   'even',
#   'fa-',
#   'thers',
#   'son',
#   'together',
#   ',',
#   'saith',
#   'lord',
#   ':',
#   'pity',
#   ',',
#   'spare',
#   ',',
#   'mercy',
#   ',',
#   'destroy',
#   '.'],
#  [':',
#   'kilroy',
#   '@',
#   'gboro.rowan.edu',
#   '(',
#   'dr',
#   'nancy',
#   "'s",
#   'sweetie',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'food',
#   'thought',
#   'tyre',
#   'summary',
#   ':',
#   'another',
#   'inerrantist',
#   'rewrite',
#   'bible',
#   '.',
#   'keywords',
#   ':',
#   'scripture',
#   ',',
#   'implication',
#   ',',
#   'prophesy',
#   ',',
#   '`',
#   'woof',
#   '!',
#   "'",
#   'organization',
#   ':',
#   'rowan',
#   'college',
#   'new',
#   'jersey',
#   'disclaimer',
#   ':',
#   'brandy',
#   'wonderdog',
#   'hope',
#   'doghouse',
#   'rebuilt',
#   '.',
#   'line',
#   ':',
#   '93',
#   'lot',
#   'discussion',
#   'tyre',
#   '.',
#   'sum',
#   ',',
#   'ezekiel',
#   'prophesied',
#   'place',
#   'would',
#   'mashed',
#   'never',
#   'rebuilt',
#   ';',
#   'lot',
#   'people',
#   'living',
#   ',',
#   'would',
#   'appear',
#   'ezekiel',
#   'literally',
#   'correct',
#   '.',
#   "n't",
#   'bother',
#   ',',
#   'understand',
#   'language',
#   'ezekiel',
#   'used',
#   'differently',
#   'so-called',
#   'biblical',
#   'literalists',
#   '.',
#   'example',
#   ',',
#   'sometimes',
#   'happens',
#   'someone',
#   'say',
#   '``',
#   'grandson',
#   'cutest',
#   'baby',
#   '!',
#   "''",
#   'turn',
#   'around',
#   'see',
#   'granddaughter',
#   'say',
#   '``',
#   'oh',
#   '!',
#   "n't",
#   'cutest',
#   'thing',
#   '!',
#   '?',
#   "''",
#   'person',
#   'literally',
#   'claiming',
#   'lined',
#   'baby',
#   'world',
#   'according',
#   'cuteness',
#   'discovered',
#   'grandchild',
#   'tied',
#   'first',
#   '.',
# ...
#   ')',
#   '<',
#   '93089.050046mvs104',
#   '@',
#   'psuvm.psu.edu',
#   '>',
#   '<',
#   '1pa6ntinns5d',
#   '@',
#   'gap.caltech.edu',
#   '>',
#   '<',
#   '1993mar30.205919.26390',
#   '@',
#   'blaze.cs.jhu.edu',
#   '>',
#   '<',
#   '1pcnp3innpom',
#   '@',
#   'gap.caltech.edu',
#   '>',
#   '<',
#   '1pdjip',
#   '$',
#   'jsi',
#   '@',
#   'fido.asd.sgi.com',
#   '>',
#   '<',
#   '1pi9jkinnqe2',
#   '@',
#   'gap.caltec',
#   'organization',
#   ':',
#   'sgi',
#   'nntp-posting-host',
#   ':',
#   'solntze.wpd.sgi.com',
#   'line',
#   ':',
#   '20',
#   'article',
#   '<',
#   '1pi9jkinnqe2',
#   '@',
#   'gap.caltech.edu',
#   '>',
#   ',',
#   'keith',
#   '@',
#   'cco.caltech.edu',
#   '(',
#   'keith',
#   'allan',
#   'schneider',
#   ')',
#   'writes',
#   ':',
#   '|',
#   '>',
#   'livesey',
#   '@',
#   'solntze.wpd.sgi.com',
#   '(',
#   'jon',
#   'livesey',
#   ')',
#   'writes',
#   ':',
#   '|',
#   '>',
#   '|',
#   '>',
#   '>',
#   '>',
#   '>',
#   'long',
#   '[',
#   'motto',
#   ']',
#   'stay',
#   'around',
#   'becomes',
#   '|',
#   '>',
#   '>',
#   '>',
#   '>',
#   'default',
#   '?',
#   '...',
#   "'s",
#   'cutoff',
#   'point',
#   '?',
#   '|',
#   '>',
#   '>',
#   '>',
#   "n't",
#   'know',
#   'exact',
#   'cutoff',
#   ',',
#   'least',
#   '|',
#   '>',
#   '>',
#   '>',
#   'year',
#   ',',
#   'surely',
#   '40',
#   'year',
#   '.',
#   '|',
#   '>',
#   '>',
#   'notion',
#   'default',
#   'take',
#   'account',
#   'change',
#   '|',
#   '>',
#   '>',
#   'population',
#   'makeup',
#   '?',
#   '|',
#   '>',
#   '|',
#   '>',
#   'specifically',
#   ',',
#   'change',
#   'talking',
#   '?',
#   'arguing',
#   '|',
#   '>',
#   'motto',
#   'interpreted',
#   'offensive',
#   'larger',
#   'portion',
#   '|',
#   '>',
#   'population',
#   '40',
#   'year',
#   'ago',
#   '?',
#   ',',
#   '?',
#   "'m",
#   'commenting',
#   'make',
#   'little',
#   'sense',
#   'consider',
#   'everything',
#   'inherit',
#   'default',
#   '.',
#   'seen',
#   'steam',
#   'train',
#   'recently',
#   '?',
#   'jon',
#   '.'],
#  ['organization',
#   ':',
#   'queen',
#   "'s",
#   'university',
#   'kingston',
#   ':',
#   'graydon',
#   '<',
#   'saundrsg',
#   '@',
#   'qucdn.queensu.ca',
#   '>',
#   'subject',
#   ':',
#   ':',
#   'gamma',
#   'ray',
#   'burster',
#   '.',
#   '?',
#   '<',
#   '1993apr24.221344.1',
#   '@',
#   'vax1.mankato.msus.edu',
#   '>',
#   'line',
#   ':',
#   '8',
#   'thing',
#   'detected',
#   'space',
#   ',',
#   'anyone',
#   'looked',
#   'possible',
#   'problem',
#   'detector',
#   '?',
#   ',',
#   'mechanism',
#   '(',
#   'cosmic',
#   'ray',
#   ',',
#   'whatever',
#   ')',
#   'could',
#   'cause',
#   'dector',
#   '_think_',
#   'seeing',
#   'one',
#   'thing',
#   '?',
#   'graydon'],
#  [':',
#   'bobbe',
#   '@',
#   'vice.ico.tek.com',
#   '(',
#   'robert',
#   'beauchaine',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'free',
#   'moral',
#   'agency',
#   'jeff',
#   'clark',
#   'organization',
#   ':',
#   'tektronix',
#   'inc.',
#   ',',
#   'beaverton',
#   ',',
#   '.',
#   'line',
#   ':',
#   '21',
#   'article',
#   '<',
#   'sandvik-140493185248',
#   '@',
#   'sandvik-kent.apple.com',
#   '>',
#   'sandvik',
#   '@',
#   'newton.apple.com',
#   '(',
#   'kent',
#   'sandvik',
#   ')',
#   'writes',
#   ':',
#   '>',
#   '>',
#   'reason',
#   'like',
#   'controversy',
#   'post-modernism',
#   ',',
#   '>',
#   'issue',
#   'polarity',
#   '--',
#   'evil',
#   'good',
#   '--',
#   'artificial',
#   '>',
#   'construct',
#   ',',
#   'fall',
#   'apart',
#   'closer',
#   'inspection',
#   '.',
#   '>',
#   '>',
#   'look',
#   'notion',
#   'constant',
#   'struggle',
#   '>',
#   'evil',
#   'good',
#   'force',
#   ',',
#   'sound',
#   'like',
#   'metaphor',
#   '>',
#   'people',
#   'assume',
#   'without',
#   'closer',
#   'inspection',
#   '.',
#   '>',
#   'info',
#   'please',
#   '.',
#   "'m",
#   'well',
#   'exposed',
#   'idea',
#   '.',
#   '/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\',
#   'bob',
#   'beauchaine',
#   'bobbe',
#   '@',
#   'vice.ico.tek.com',
#   'said',
#   'queen',
#   'could',
#   'stay',
#   ',',
#   'blew',
#   'bronx',
#   'away',
#   ',',
#   'sank',
#   'manhattan',
#   'sea',
#   '.',
#   '^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^'],
#  [':',
#   'rjl+',
#   '@',
#   'pitt.edu',
#   '(',
#   'richard',
#   'j.',
#   'loether',
#   ')',
#   'subject',
#   ':',
#   ':',
#   "'s",
#   'next',
#   '?',
#   'mormon',
#   'jew',
#   '?',
#   'distribution',
#   ':',
#   'usa',
#   'organization',
#   ':',
#   'university',
#   'pittsburgh',
#   'line',
#   ':',
#   '38',
#   'article',
#   '<',
#   '1r1et6innh8p',
#   '@',
#   'ctron-news.ctron.com',
#   '>',
#   'king',
#   '@',
#   'ctron.com',
#   '(',
#   'john',
#   'e.',
#   'king',
#   ')',
#   'writes',
#   ':',
#   ':',
#   ':',
#   'pmy',
#   '@',
#   'vivaldi.acc.virginia.edu',
#   '(',
#   'pete',
#   'yadlowsky',
#   ')',
#   'writes',
#   ':',
#   ':',
#   ':',
#   ':',
#   ':',
#   "n't",
#   'christ',
#   'tell',
#   'disciple',
#   'arm',
#   'self',
#   ',',
#   'shortly',
#   ':',
#   ':',
#   ':',
#   'crusifiction',
#   '?',
#   '(',
#   'believe',
#   'exact',
#   'quote',
#   'along',
#   ':',
#   ':',
#   ':',
#   'line',
#   ',',
#   '``',
#   '[',
#   'something',
#   ']',
#   'sell',
#   'buy',
#   'sword',
#   '.',
#   "''",
#   ')',
#   ':',
#   ':',
#   ':this',
#   'guy',
#   'preached',
#   'love',
#   ',',
#   'deference',
#   'power',
#   'god',
#   ':',
#   ':renunciation',
#   'worldly',
#   'life',
#   'exchange',
#   'life',
#   'spirit',
#   '?',
#   ':',
#   ':jesus',
#   'fact',
#   'command',
#   'disciple',
#   'arm',
#   ',',
#   'would',
#   ':',
#   ':take',
#   'yet',
#   'another',
#   'reason',
#   'reject',
#   'christian',
#   'doctrine',
#   ',',
#   ':',
#   ':whatever',
#   "'s",
#   'worth',
#   '.',
#   'like',
#   'religion',
#   ',',
#   'doctrine',
#   'good',
#   'bad',
#   '.',
#   'would',
#   'certainly',
#   'reject',
#   'current',
#   'implementation',
#   'doctrine',
#   '.',
#   ':',
#   ':',
#   '.',
#   'classic',
#   'example',
#   'taking',
#   'scripture',
#   'context',
#   '.',
#   ':',
#   "'s",
#   'taken',
#   'luke',
#   '22:36.',
#   'note',
#   'v',
#   '37',
#   ';',
#   '``',
#   'tell',
#   ':',
#   'written',
#   'must',
#   'accomplished',
#   ',',
#   'namely',
#   ',',
#   "'and",
#   'reckoned',
#   ':',
#   'lawless',
#   'one',
#   "'",
#   '...',
#   "''",
#   '.',
#   'stated',
#   'two',
#   'sword',
#   'enough',
#   ':',
#   'group',
#   'carry',
#   'counted',
#   'lawless',
#   '.',
#   'politically',
#   'correct',
#   'number',
#   'weapon',
#   'cause',
#   'arresed',
#   'killed',
#   'even',
#   ',',
#   'huh',
#   '?',
#   ':',
#   'jesus',
#   "'",
#   'overiding',
#   'message',
#   'one',
#   'peace',
#   '(',
#   'turn',
#   'cheek',
#   ';',
#   'live',
#   ':',
#   'sword',
#   'die',
#   'sword',
#   ';',
#   'etc',
#   ')',
#   '.',
#   'yes',
#   ',',
#   'course',
#   ',',
#   'matthew',
#   '10:34-35',
#   '``',
#   'suppose',
#   'come',
#   'bring',
#   'peace',
#   'earth',
#   ';',
#   'peace',
#   'come',
#   'bring',
#   'sword',
#   '...',
#   "''",
#   ':',
#   'rjl',
#   '--',
#   'rich',
#   'loether',
#   'snail',
#   'mail',
#   ':',
#   'university',
#   'pittsburgh',
#   'idea',
#   ':',
#   'email',
#   ':',
#   'rjl+',
#   '@',
#   'pitt.edu',
#   'computing',
#   'info',
#   'service',
#   'mine',
#   ',',
#   'voice',
#   ':',
#   '(',
#   '412',
#   ')',
#   '624-6429',
#   '600',
#   'epsilon',
#   'drive',
#   'fax',
#   ':',
#   '(',
#   '412',
#   ')',
#   '624-6426',
#   'pittsburgh',
#   ',',
#   'pa',
#   '15238',
#   'mine',
#   '.'],
#  [':',
#   'livesey',
#   '@',
#   'solntze.wpd.sgi.com',
#   '(',
#   'jon',
#   'livesey',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'anecdote',
#   'islam',
#   'organization',
#   ':',
#   'sgi',
#   'line',
#   ':',
#   '15',
#   'distribution',
#   ':',
#   'world',
#   'nntp-posting-host',
#   ':',
#   'solntze.wpd.sgi.com',
#   'article',
#   '<',
#   '114127',
#   '@',
#   'bu.edu',
#   '>',
#   ',',
#   'jaeger',
#   '@',
#   'buphy.bu.edu',
#   '(',
#   'gregg',
#   'jaeger',
#   ')',
#   'writes',
#   ':',
#   '|',
#   '>',
#   '|',
#   '>',
#   "n't",
#   'understand',
#   'point',
#   'petty',
#   'sarcasm',
#   '.',
#   'basic',
#   '|',
#   '>',
#   'principle',
#   'islam',
#   'one',
#   'born',
#   'muslim',
#   'one',
#   'say',
#   '``',
#   'testify',
#   '|',
#   '>',
#   'god',
#   'god',
#   'mohammad',
#   'prophet',
#   'god',
#   "''",
#   ',',
#   '|',
#   '>',
#   'long',
#   'one',
#   'explicitly',
#   'reject',
#   'islam',
#   'word',
#   'one',
#   '_must_',
#   '|',
#   '>',
#   'considered',
#   'muslim',
#   'muslim',
#   '.',
#   'phenomenon',
#   "'re",
#   'attempting',
#   '|',
#   '>',
#   'make',
#   'general',
#   'rule',
#   'psychology',
#   'direct',
#   'odds',
#   'basic',
#   '|',
#   '>',
#   'islamic',
#   'principle',
#   '.',
#   'want',
#   'attack',
#   'islam',
#   'could',
#   'better',
#   '|',
#   '>',
#   'argue',
#   'something',
#   'islam',
#   'explicitly',
#   'contradicts',
#   '.',
#   'mr',
#   'mozumder',
#   'incorrect',
#   'say',
#   'committing',
#   'bad',
#   'act',
#   ',',
#   'people',
#   'temporarily',
#   'become',
#   'atheist',
#   '?',
#   'jon',
#   '.'],
#  [':',
#   'rnapier',
#   '@',
#   'csugrad.cs.vt.edu',
#   '(',
#   'rob',
#   'napier',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'oto',
#   ',',
#   'ancient',
#   'order',
#   'oriental',
#   'templar',
#   'organization',
#   ':',
#   'virginia',
#   'tech',
#   'computer',
#   'science',
#   'dept',
#   ',',
#   'blacksburg',
#   ',',
#   'va',
#   'line',
#   ':',
#   '21',
#   'distribution',
#   ':',
#   'world',
#   'nntp-posting-host',
#   ':',
#   'csugrad.cs.vt.edu',
#   'article',
#   '<',
#   '79615',
#   '@',
#   'cup.portal.com',
#   '>',
#   'thyagi',
#   '@',
#   'cup.portal.com',
#   '(',
#   'thyagi',
#   'morgoth',
#   'nagasiva',
#   ')',
#   'writes',
#   ':',
#   '>',
#   '>',
#   '>',
#   "''",
#   'may',
#   'concern',
#   '-',
#   '>',
#   '[',
#   'constitution',
#   'sacrificed',
#   'bandwidth',
#   'god',
#   ']',
#   'im',
#   'glad',
#   'finally',
#   'heard',
#   'exactly',
#   'oto',
#   '.',
#   'finally',
#   'know',
#   'stop',
#   'looking',
#   ',',
#   'content',
#   'knowlege',
#   'im',
#   'interested',
#   '.',
#   "'s",
#   'tough',
#   'enough',
#   'listening',
#   'religion',
#   'refer',
#   "''",
#   'one',
#   'truth',
#   "''",
#   '.',
#   'possibly',
#   'accept',
#   'magical',
#   'order',
#   '?',
#   '``',
#   'answer',
#   'give',
#   'join',
#   'u',
#   '(',
#   'pay',
#   'due',
#   ')',
#   '?',
#   "''",
#   'scary',
#   '.',
#   'besides',
#   ',',
#   'answer',
#   'easy',
#   '.',
#   'question',
#   '!',
#   "'s",
#   'another',
#   'story',
#   '...',
#   'rintaw',
#   '--',
#   '|',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '|',
#   'rob',
#   'napier',
#   '-',
#   'virginia',
#   'tech',
#   '|',
#   'gravity',
#   ',',
#   'earth',
#   'suck',
#   '.',
#   '|',
#   '|',
#   'rnapier',
#   '@',
#   'csugrad.cs.vt.edu',
#   '|',
#   "'m",
#   'another',
#   'schitz',
#   'hall',
#   '|',
#   '|',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '-|'],
#  ['organization',
#   ':',
#   'queen',
#   "'s",
#   'university',
#   'kingston',
#   ':',
#   'graydon',
#   '<',
#   'saundrsg',
#   '@',
#   'qucdn.queensu.ca',
#   '>',
#   'subject',
#   ':',
#   ':',
#   'ussr',
#   'reached',
#   'moon',
#   'first',
#   '?',
#   '<',
#   'dxb105.734155421',
#   '@',
#   'aries',
#   '>',
#   '<',
#   '1993apr7.124724.22534',
#   '@',
#   'yang.earlham.edu',
#   '>',
#   '<',
#   'dxb105.734495289',
#   '@',
#   'virgo',
#   '>',
#   '<',
#   '1993apr12.161742.22647',
#   '@',
#   'yang.earlham.edu',
#   '>',
#   '<',
#   '93107.144339saundrsg',
#   '@',
#   'qucdn.queensu.ca',
#   '>',
#   '<',
#   '1993apr18.091051.14496',
#   '@',
#   'ke4zv.uucp',
#   '>',
#   'line',
#   ':',
#   '38',
#   'article',
#   '<',
#   '1993apr18.091051.14496',
#   '@',
#   'ke4zv.uucp',
#   '>',
#   ',',
#   'gary',
#   '@',
#   'ke4zv.uucp',
#   '(',
#   'gary',
#   'coffman',
#   ')',
#   'say',
#   ':',
#   '>',
#   'article',
#   '<',
#   '93107.144339saundrsg',
#   '@',
#   'qucdn.queensu.ca',
#   '>',
#   'graydon',
#   '>',
#   '<',
#   'saundrsg',
#   '@',
#   'qucdn.queensu.ca',
#   '>',
#   'writes',
#   ':',
#   '>',
#   '>',
#   'turning',
#   "'what",
#   "'s",
#   'moonbase',
#   'good',
#   "'",
#   ',',
#   'ought',
#   '>',
#   '>',
#   'post',
#   "'ve",
#   'hundred',
#   'odd',
#   'post',
#   'go',
#   ',',
#   'would',
#   '>',
#   '>',
#   'think',
#   'real',
#   'reason',
#   'moon',
#   'base',
#   'economic',
#   '.',
#   '>',
#   '>',
#   'since',
#   'someone',
#   'space',
#   'industry',
#   'presumeably',
#   'much',
#   '>',
#   '>',
#   'larger',
#   'gnp',
#   'would',
#   '_without_',
#   'space',
#   'industry',
#   ',',
#   'eventually',
#   ',',
#   '>',
#   '>',
#   'simply',
#   'able',
#   'afford',
#   'stuff',
#   '.',
#   '>',
#   '>',
#   'read',
#   'right',
#   ',',
#   "'re",
#   'saying',
#   'essence',
#   ',',
#   'larger',
#   '>',
#   'economy',
#   ',',
#   'nation',
#   'discretionary',
#   'fund',
#   '*',
#   'waste',
#   '*',
#   '>',
#   'lunar',
#   'facility',
#   '.',
#   'certainly',
#   'partially',
#   'case',
#   'apollo',
#   ',',
#   '>',
#   'real',
#   'lunar',
#   'colony',
#   'probably',
#   'require',
#   'continuing',
#   'military',
#   ',',
#   '>',
#   'scientific',
#   ',',
#   'commercial',
#   'reason',
#   'rather',
#   '``',
#   '>',
#   'money',
#   ',',
#   '?',
#   "''",
#   'approach',
#   '.',
#   'assuming',
#   'wo',
#   "n't",
#   'moon',
#   'base',
#   'unless',
#   'make',
#   'profit',
#   ',',
#   'actually',
#   '.',
#   ',',
#   'well',
#   ',',
#   'give',
#   'larger',
#   'gnp',
#   'lead',
#   'able',
#   'spend',
#   'money',
#   'military',
#   ',',
#   'including',
#   'gosh-wow',
#   'space',
#   'stuff',
#   '.',
#   '(',
#   'assuming',
#   "'s",
#   'profitable',
#   ',',
#   'rather',
#   'paying',
#   '.',
#   ')',
#   '>',
#   '>',
#   "'s",
#   'conceivable',
#   'luna',
#   'military',
#   'purpose',
#   ',',
#   "'s",
#   'possible',
#   '>',
#   'luna',
#   'commercial',
#   'purpose',
#   ',',
#   "'s",
#   'likely',
#   '>',
#   'luna',
#   'scientific',
#   'purpose',
#   'next',
#   'several',
#   'hundred',
#   '>',
#   'year',
#   'least',
#   '.',
#   'therefore',
#   ',',
#   'lunar',
#   'base',
#   'predicated',
#   'funding',
#   '>',
#   'level',
#   'little',
#   'different',
#   'found',
#   'antarctic',
#   'base',
#   '.',
#   '>',
#   'put',
#   '200',
#   'person',
#   'base',
#   'moon',
#   '$',
#   '30',
#   'million',
#   'year',
#   '?',
#   'even',
#   '>',
#   'use',
#   'grad',
#   'student',
#   '?',
#   'might',
#   'able',
#   '_run_',
#   'one',
#   ';',
#   'put',
#   ',',
#   'hardly',
#   '.',
#   'think',
#   'least',
#   'couple',
#   'century',
#   'significant',
#   'commerical',
#   'activity',
#   'moon',
#   '?',
#   'graydon'],
#  [':',
#   'pgf',
#   '@',
#   'srl03.cacs.usl.edu',
#   '(',
#   'phil',
#   'g.',
#   'fraering',
#   ')',
#   'subject',
#   ':',
#   ':',
#   'space',
#   'research',
#   'spin',
#   'organization',
#   ':',
#   'univ',
#   '.',
#   'southwestern',
#   'louisiana',
#   'line',
#   ':',
#   '37',
#   'shafer',
#   '@',
#   'rigel.dfrf.nasa.gov',
#   '(',
#   'mary',
#   'shafer',
#   ')',
#   'writes',
#   ':',
#   '>',
#   '4',
#   'apr',
#   '1993',
#   '20:31:10',
#   '-0400',
#   ',',
#   'prb',
#   '@',
#   'access.digex.com',
#   '(',
#   'pat',
#   ')',
#   'said',
#   ':',
#   '>',
#   'pat',
#   '>',
#   'article',
#   '<',
#   '1993apr2.213917.1',
#   '@',
#   'aurora.alaska.edu',
#   '>',
#   '>',
#   'pat',
#   '>',
#   'nsmca',
#   '@',
#   'aurora.alaska.edu',
#   'writes',
#   ':',
#   '>',
#   '>',
#   'question',
#   'someone',
#   'give',
#   '10',
#   'example',
#   'direct',
#   'nasa/space',
#   'related',
#   '>',
#   '>',
#   'research',
#   'helped',
#   'humanity',
#   'general',
#   '?',
#   'interesting',
#   'see',
#   '..',
#   '>',
#   'pat',
#   '>',
#   'tang',
#   ':',
#   '-',
#   ')',
#   'mylar',
#   'think',
#   '.',
#   'think',
#   'also',
#   'pushed',
#   'hi',
#   'tech',
#   '>',
#   'pat',
#   '>',
#   'composite',
#   'airframe',
#   '.',
#   'look',
#   'fly',
#   'wire',
#   '.',
#   '>',
#   'swept',
#   'wing',
#   '--',
#   'fly',
#   'airliner',
#   "'ve",
#   'reaped',
#   'benefit',
#   '.',
#   "n't",
#   'one',
#   'early',
#   'jet',
#   'fighter',
#   '?',
#   'also',
#   'think',
#   'german',
#   'work',
#   'wwii',
#   '.',
#   '>',
#   'winglets',
#   '.',
#   'area',
#   'ruling',
#   '.',
#   'digital',
#   'fly',
#   'wire',
#   '.',
#   'ride',
#   'smoothing',
#   '.',
#   'lot',
#   'also',
#   'done',
#   'military',
#   '...',
#   '>',
#   'microwave',
#   'landing',
#   'system',
#   '.',
#   'supercritical',
#   'wing',
#   '.',
#   'general',
#   'aviation',
#   '>',
#   'air',
#   'foil',
#   '.',
#   "n't",
#   'first',
#   'microwave',
#   'landing',
#   'system',
#   'wwii',
#   '?',
#   '>',
#   '--',
#   '>',
#   'mary',
#   'shafer',
#   'dod',
#   '#',
#   '0362',
#   'kotfr',
#   'nasa',
#   'dryden',
#   'flight',
#   'research',
#   'facility',
#   ',',
#   'edward',
#   ',',
#   'ca',
#   '>',
#   'shafer',
#   '@',
#   'rigel.dfrf.nasa.gov',
#   'course',
#   "n't",
#   'speak',
#   'nasa',
#   '>',
#   '``',
#   'mig',
#   'six',
#   'better',
#   'mig',
#   '.',
#   "''",
#   'unknown',
#   'u',
#   'fighter',
#   'pilot',
#   'egad',
#   '!',
#   "'m",
#   'disagreeing',
#   'mary',
#   'shafer',
#   '!',
#   '--',
#   'phil',
#   'fraering',
#   '|',
#   "''",
#   'seems',
#   'like',
#   'every',
#   'day',
#   'find',
#   'sort',
#   'stuff',
#   '.',
#   'pgf',
#   '@',
#   'srl02.cacs.usl.edu|like',
#   'ancient',
#   'mayan',
#   'televison',
#   '.',
#   "''",
#   'repo',
#   'man']]

# %%
print(embeddings_trained['mayan'])
# Out:
# [-0.09698242  0.06533806 -0.02749158 -0.03666175  0.08253359 -0.21133956
#   0.1344139   0.34522894 -0.0044253  -0.07066055 -0.00569259 -0.20810474
#  -0.00794785  0.1143237   0.06015522 -0.09028698  0.0987249  -0.03464363
#   0.03715667 -0.17077829  0.1347763  -0.04116195  0.0841218   0.10655913
#   0.04998249 -0.00938493 -0.08865639 -0.027421   -0.00471199 -0.13502459
#   0.25931317  0.02150917 -0.06579052  0.03338759  0.00747669  0.03739978
#   0.15821867 -0.02697811  0.02901728 -0.13833229 -0.06902765 -0.06694841
#  -0.04832347  0.02341224 -0.02107115 -0.05315732 -0.10969694  0.07236032
#   0.00471849  0.02209474  0.10583793 -0.08080926 -0.15760626  0.09237207
#  -0.06502321  0.02138214  0.17320193  0.03613878 -0.06139112  0.04437254
#  -0.06865576 -0.00187204  0.14867789  0.00823332 -0.0661395   0.17201592
#  -0.02471379  0.01521694 -0.10863293  0.20650762 -0.00194942  0.10393227
#   0.09910091  0.02909979  0.08663645 -0.09516289 -0.03888625  0.16281028
#  -0.14636579 -0.01026494 -0.03673351  0.01479185 -0.04419541  0.16464959
#   0.00747394  0.08620606  0.0590561   0.05756262  0.1104826   0.01567686
#   0.06913853  0.02235606  0.20863697 -0.06946356  0.2852217   0.05461437
#   0.12366828 -0.10705557  0.05357728  0.02717953]
